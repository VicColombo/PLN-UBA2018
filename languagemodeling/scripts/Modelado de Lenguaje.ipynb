# %% [markdown]
# # Contando N-Gramas

# %%
#from nltk.corpus import gutenberg
#sents = list(gutenberg.sents('austen-emma.txt'))

from nltk.corpus import PlaintextCorpusReader
corpus = PlaintextCorpusReader('/home/magickmechelle/Escritorio/CosasPLN2018/PLN-UBA2018', 'actas_01-01-2016_01-09-2016.txt')
sents = list(corpus.sents())

# %% [markdown]
# Primero vemos cómo imprimir todos los trigramas de una sola oración:

# %%
sent = sents[0]

n = 3  # trigramas
for i in range(len(sent) - n + 1): 
    print(sent[i:i+n])
# Out:
# ['RERUM', 'S', '.']
# ['S', '.', 'A']
# ['.', 'A', '.']
# ['A', '.', '1']
# ['.', '1', ')']
# ['1', ')', 'Luis']
# [')', 'Luis', 'José']
# ['Luis', 'José', 'Armando']
# ['José', 'Armando', ',']
# ['Armando', ',', 'médico']
# [',', 'médico', ',']
# ['médico', ',', '63']
# [',', '63', 'años']
# ['63', 'años', ',']
# ['años', ',', 'DNI']
# [',', 'DNI', '10249992']
# ['DNI', '10249992', 'y']
# ['10249992', 'y', 'Ana']
# ['y', 'Ana', 'Carolina']
# ['Ana', 'Carolina', 'Facchin']
# ['Carolina', 'Facchin', ',']
# ['Facchin', ',', 'comerciante']
# [',', 'comerciante', ',']
# ['comerciante', ',', '40']
# [',', '40', 'años']
# ['40', 'años', ',']
# ['años', ',', 'DNI']
# [',', 'DNI', '29712744']
# ['DNI', '29712744', ';']
# ['29712744', ';', 'ambos']
# [';', 'ambos', 'argentinos']
# ['ambos', 'argentinos', ',']
# ['argentinos', ',', 'casados']
# [',', 'casados', ',']
# ['casados', ',', 'domiciliados']
# [',', 'domiciliados', 'en']
# ['domiciliados', 'en', 'Ruta']
# ['en', 'Ruta', 'E']
# ['Ruta', 'E', '-']
# ['E', '-', '57']
# ['-', '57', 'Km16']
# ['57', 'Km16', 'Manzana']
# ['Km16', 'Manzana', '1']
# ['Manzana', '1', 'Lote']
# ['1', 'Lote', '28']
# ['Lote', '28', 'Barrio']
# ['28', 'Barrio', 'Cuatro']
# ['Barrio', 'Cuatro', 'Hojas']
# ['Cuatro', 'Hojas', ',']
# ['Hojas', ',', 'Mendiolaza']
# [',', 'Mendiolaza', 'Departamento']
# ['Mendiolaza', 'Departamento', 'Colón']
# ['Departamento', 'Colón', 'Provincia']
# ['Colón', 'Provincia', 'de']
# ['Provincia', 'de', 'Córdoba']
# ['de', 'Córdoba', '.']

# %% [markdown]
# Ahora veamos cómo contar los trigramas de todas las oraciones:

# %%
from collections import defaultdict

countN = defaultdict(int) #cuento n gramas
countMenosUn = defaultdict(int) #cuento n-1 gramas

n = 3
m = n-1
for sent in sents:
    for i in range(len(sent) - n + 1): #-n+1 está restando para no pasarse
        ngram = tuple(sent[i:i+n])  # los diccionarios no pueden guardar listas, pero sí tuplas: ent[i:i+n es una lista, lo está convirtiendo en tupla
        countN[ngram] += 1
    for i in range(len(sent) - m + 1): 
        ngram = tuple(sent[i:i+m])  
        countMenosUn[ngram] += 1

# %%
countN
# Out:
# defaultdict(int,
#             {('Julio', 'de', '1980'): 1,
#              ('Mayo', '972', 'piso'): 2,
#              ('Salguero', '1294', ','): 1,
#              ('Magaly', 'Macieri', '-'): 4,
#              ('23', '-', '29434627'): 2,
#              (')', 'realizar', 'asesorías'): 1,
#              ('su', 'construcción', ','): 2,
#              ('social', ':', 'Simbrón'): 1,
#              ('inmuebles', 'para', 'construirlos'): 1,
#              (',', 'las', 'de'): 1,
#              ('3223', ',', 'se'): 1,
#              ('comercialización', 'de', 'alimentos'): 1,
#              ('Dominico', ',', 'Avellaneda'): 1,
#              ('y', 'sistemas', 'para'): 3,
#              ('Teófilo', 'Soae', 'argentino'): 1,
#              ('323', '.', '070'): 1,
#              ('de', 'operaciones', 'inmobiliarias'): 121,
#              ('RUSSO', ';', 'ambos'): 1,
#              ('Ciudad', 'Metepec', ','): 1,
#              (')', 'Viamonte', '658'): 1,
#              ('metodologías', 'y', 'mecánicas'): 1,
#              ('26', '.', '281'): 1,
#              ('DNI', '13799406', ','): 1,
#              ('de', 'hojas', 'sueltas'): 1,
#              ('avícolas', 'y', 'forestales'): 1,
#              ('limpieza', 'y', 'todo'): 1,
#              ('30', '.', '450'): 1,
#              ('hechos', 'publicitarios', 'de'): 1,
#              ('instalaciones', 'diversas', ','): 1,
#              ('años', 'Cierre', 'ejercicio'): 1,
#              ('como', 'gestor', 'de'): 1,
#              (';', 'ambas', 'por'): 1,
#              ('venta', ',', 'mandato'): 1,
#              ('animales', 'aplicados', 'a'): 2,
#              ('25', '/', '06'): 8,
#              ('de', 'implementos', 'de'): 1,
#              (':', 'Udaondo', '1260'): 1,
#              ('Presidente', ':', 'Guillermo'): 16,
#              ('LLANOS', 'S', '.'): 1,
#              ('caucho', ',', 'plástico'): 1,
#              (':', 'Analia', 'Noelia'): 1,
#              ('Leonardo', 'Carlos', 'Barragan'): 1,
#              ('se', 'dicte', 'en'): 16,
#              ('Libro', '60', 'Tomo'): 2,
#              ('técnico', 'y', 'de'): 1,
#              ('y', 'la', 'compra'): 8,
#              ('en', 'plantas', 'compresoras'): 1,
#              ('pidió', 'Gonzalez', '4680'): 1,
#              ('campos', 'propios', 'como'): 1,
#              ('equipamiento', 'informático', 'de'): 1,
#              (';', 'atención', 'al'): 1,
#              ('Abd', 'El', 'Jalil'): 1,
#              ('4334', 'C', '.'): 2,
#              ('facturas', ',', 'moneda'): 1,
#              (';', 'y', 'CESAR'): 1,
#              ('92', '.', '106'): 1,
#              ('Jorge', 'Omar', 'DEVITO'): 2,
#              ('Torre', ',', 'ambos'): 1,
#              ('argentino', ',', 'casados'): 1,
#              ('distribución', 'de', 'todos'): 3,
#              ('07744882', '-', '9'): 1,
#              ('Postiglione', ',', 'ambos'): 1,
#              ('servicios', ',', 'con'): 1,
#              ('Amaniche', '-', 'T'): 2,
#              ('1983', ',', 'casado'): 7,
#              ('INFINITO', 'AR', 'S'): 4,
#              ('20', '-', '23701096'): 1,
#              ('CLEVER', 'DONKEY', 'SA'): 1,
#              ('la', 'prestación', ','): 7,
#              ('Objeto', ':', 'desarrollar'): 3,
#              ('62', 'del', '15'): 1,
#              ('Nº', '1430', 'Claudio'): 1,
#              ('nombres', 'comerciales', 'y'): 2,
#              ('agrícola', 'ganadera', 'de'): 1,
#              ('calle', 'Florida', '826'): 2,
#              ('mencionados', '“', 'ut'): 1,
#              ('las', 'producciones', 'de'): 2,
#              ('Julio', 'Cesar', 'BELLONE'): 1,
#              ('y', 'extranet', ','): 2,
#              ('Fraga', '86', 'piso'): 1,
#              ('Rivadavia', '555', 'Puerto'): 1,
#              ('o', 'trabajos', 'de'): 1,
#              ('Chubut', ',', 'Gabriel'): 1,
#              ('y', 'taller', 'de'): 1,
#              ('o', 'contaminantes', ','): 1,
#              (':', 'Elena', 'Margarita'): 1,
#              ('Suplente', ':', 'Juana'): 3,
#              ('.', '625', 'y'): 1,
#              ('Magali', 'Ginette', 'Zayat'): 1,
#              (',', 'máquinas', 'agrícolas'): 1,
#              ('.', 'Fridman', 'Registro'): 4,
#              ('Pesos', ':', '100'): 1,
#              ('fines', '.”', 'Autorizado'): 1,
#              ('Lopez', 'Lopez', '-'): 2,
#              ('granos', ',', 'comercialización'): 1,
#              ('del', 'Libro', 'número'): 1,
#              ('990', ',', '4º'): 1,
#              ('/', 'o', 'cláusula'): 1,
#              ('37843265', ',', 'Madre'): 1,
#              ('Miguel', 'Gersberg', 'acepto'): 1,
#              ('GIOVANNI', ',', 'argentino'): 3,
#              ('Avenida', 'Boyacá', '372'): 1,
#              ('facilitar', 'la', 'interacción'): 4,
#              ('.', '999', ','): 6,
#              ('Registro', 'notarial', 'N'): 1,
#              ('°', '4028', '/'): 1,
#              ('confeccionadas', 'con', 'pieles'): 1,
#              ('Corona', 'Golf', 'club'): 1,
#              ('°:', '383', 'C'): 9,
#              ('tareas', 'que', 'requieran'): 6,
#              ('reactivos', 'para', 'análisis'): 1,
#              (',', 'letras', 'corpóreas'): 1,
#              ('la', 'consultaría', 'e'): 5,
#              ('Nº', '482', 'José'): 13,
#              ('DNI', '24591665', ','): 1,
#              ('presidente', ':', 'Susana'): 1,
#              ('RODRIGUEZ', ',', 'ambos'): 2,
#              ('comerciali', '-', 'zación'): 1,
#              ('1', ',', 'Lanifur'): 1,
#              ('solares', 'o', 'de'): 1,
#              ('Corsan', 'I', ','): 1,
#              (',', 'auxilio', 'y'): 1,
#              ('CASCO', 'CABAÑA', 'TRES'): 1,
#              ('REAL', 'EN', 'LA'): 1,
#              ('Díaz', '2247', ','): 1,
#              (';', 'domicilio', 'Boris'): 1,
#              (')', 'cada', 'una'): 12,
#              ('reparación', 'y', 'diseño'): 2,
#              ('de', 'empresas', 'relacionadas'): 3,
#              ('.', '580', '.'): 1,
#              ('23', '-', '111606743'): 1,
#              ('N', '°', '20791'): 1,
#              ('3º', 'del', 'Estatuto'): 2,
#              ('publicitarias', ',', 'etcétera'): 1,
#              ('empresarios', 'e', 'institucionales'): 2,
#              (',', 'velas', 'de'): 1,
#              ('dinero', 'en', 'moneda'): 1,
#              (',', 'Colombres', '447'): 2,
#              ('con', 'equipos', 'propios'): 11,
#              ('256', ',', '7'): 1,
#              ('DNI', '23365059', ','): 1,
#              ('agua', 'y', 'residuos'): 1,
#              ('STEVERLYNCK', ';', 'DIRECTOR'): 1,
#              ('constituir', 'leasing', 'sobre'): 2,
#              ('CEE', '00001338e', '.'): 1,
#              ('acto', 'y', 'fijaron'): 2,
#              ('e', 'investigaciones', 'de'): 1,
#              ('27', '.', '211'): 1,
#              ('de', 'Presidente', 'del'): 3,
#              ('Ignacio', 'FERNANDEZ', ','): 1,
#              (',', 'departamentos', ','): 5,
#              ('Bolivia', '1625', 'CABA'): 1,
#              ('Matrícula', ':', '4465'): 3,
#              ('y', 'auxiliares', 'relacionados'): 1,
#              ('con', 'cualquier', 'destino'): 2,
#              ('atención', 'de', 'todo'): 1,
#              ('pasamaneria', ',', 'articulos'): 2,
#              ('de', 'realizarse', ','): 1,
#              (':', 'Paraguay', '541'): 2,
#              ('agrícola', ',', 'tractores'): 1,
#              ('operaciones', 'tendientes', 'al'): 1,
#              ('N', '°', '9'): 1,
#              ('Suplente', ':', 'Vanina'): 4,
#              ('diversiones', 'electrónicas', 'y'): 1,
#              (',', 'y', 'contratos'): 1,
#              ('objeto', 'efectuar', 'por'): 2,
#              ('adjudicaciones', ',', 'justificaciones'): 1,
#              ('Nº', '1538', 'Regina'): 4,
#              ('prestar', 'otros', 'servicios'): 5,
#              ('Maria', 'Campos', '559'): 1,
#              ('N', '°', '514'): 1,
#              ('baja', 'depto', ','): 1,
#              ('de', 'la', 'totalidad'): 1,
#              ('orientada', 'al', 'desarrollo'): 1,
#              ('29403', '/', '16'): 1,
#              ('Matrícula', ':', '4797'): 1,
#              ('Operaciones', 'agrícola', 'ganaderas'): 1,
#              ('de', 'uso', 'hospitalario'): 1,
#              ('Argentina', 'como', 'agente'): 1,
#              ('calle', 'Luis', 'Viale'): 1,
#              ('real', 'en', 'Arcos'): 3,
#              ('hormigón', 'armado', 'y'): 1,
#              ('facilitar', 'todas', 'o'): 1,
#              ('Cerrito', '1370', ','): 3,
#              ('54', 'Escribana', 'Liliana'): 1,
#              ('N', '°', '45436'): 1,
#              (',', 'Martín', 'Rodriguez'): 4,
#              ('N', '°', '54774'): 1,
#              ('BERNAL', 'SCRAP', 'S'): 1,
#              (');', 'y', 'Ricardo'): 1,
#              ('BORDON', 'NOCEDA', '.'): 1,
#              ('inmuebles', ',', 'cualquiera'): 1,
#              ('e', 'Importación', 'en'): 1,
#              ('26', '.', '460'): 8,
#              ('Alfredo', 'PEREYRA', ';'): 1,
#              ('2', '”,', 'CABA'): 6,
#              ('comercial', 'de', ':'): 1,
#              ('KEMEX', 'S', '.'): 1,
#              (',', 'prehorizontalidad', 'y'): 1,
#              ('complementarios', 'al', 'servicio'): 2,
#              ('75', ',', 'calle'): 2,
#              ('2', '-', '59'): 1,
#              ('artesanal', ',', 'y'): 1,
#              ('o', 'afines', 'al'): 1,
#              ('vacantes', ',', 'expropiaciones'): 1,
#              ('Pillado', ',', 'con'): 1,
#              ('y', 'el', 'diseño'): 3,
#              (':', 'Leandro', 'Ariel'): 5,
#              ('000', ',', 'representada'): 3,
#              ('09', '/', '1943'): 2,
#              (',', 'herrajes', ','): 6,
#              ('5988', '/', '16'): 1,
#              ('A', ',', 'PRESIDENTE'): 1,
#              (',', 'de', 'mercancías'): 2,
#              ('Guillermo', 'Eduardo', 'Quiñoa'): 1,
#              ('computación', ',', 'útiles'): 1,
#              ('Emilio', 'BITAR', ','): 2,
#              ('474', ',', 'CUIT'): 1,
#              ('BAMBOZZI', ',', 'argentino'): 3,
#              ('Escritura', '03', '/'): 1,
#              ('2', ')', 'LOS'): 2,
#              ('por', 'vía', 'postal'): 1,
#              ('y', 'crédito', 'en'): 1,
#              ('y', '244', 'ley'): 1,
#              ('clase', 'y', 'tamaño'): 1,
#              ('dpto', '“', '7'): 1,
#              ('Pesos', 'seis', 'millones'): 1,
#              ('DABBAH', ',', 'argentino'): 2,
#              ('naturaleza', 'y', 'los'): 4,
#              ('López', 'con', 'domicilio'): 1,
#              ('Córdoba', '1821', 'Planta'): 1,
#              ('estatales', ',', 'servicios'): 2,
#              ('Suplente', ':', 'Soledad'): 2,
#              ('galpones', ',', 'diques'): 2,
#              ('41599', '/', '16'): 1,
#              ('taxis', ',', 'fletes'): 1,
#              (';', 'facilitar', 'capitales'): 1,
#              (':', 'Federico', 'Antonio'): 2,
#              ('moldes', 'plásticos', 'inyectados'): 1,
#              ('y', 'realizar', 'negocios'): 1,
#              ('N', '°', '12132'): 1,
#              (':', 'Matías', 'Leandro'): 1,
#              ('Draft', 'S', '.'): 1,
#              (')', 'Simbrón', '4439'): 1,
#              ('Pietra', ';', 'Director'): 1,
#              ('controles', 'de', 'cortinas'): 1,
#              ('125', ',', 'CUIT'): 1,
#              ('de', 'cualesquiera', 'servicios'): 3,
#              ('impresión', 'de', 'diseños'): 1,
#              ('por', 'objeto', 'Prestación'): 1,
#              ('otorgamiento', 'de', 'poderes'): 2,
#              ('los', 'artículos', ':'): 1,
#              ('Directorio', ':', 'mínimo'): 3,
#              ('Heladoking', 'S', '.'): 1,
#              ('comedores', 'en', 'general'): 1,
#              ('17', 'del', '16'): 1,
#              ('523', '.', '001'): 1,
#              ('con', 'la', 'implantación'): 1,
#              ('46', 'años', ','): 2,
#              ('142', 'del', '24'): 2,
#              ('técnico', 'en', 'computación'): 4,
#              ('y', 'Osvaldo', 'Ramón'): 1,
#              ('departamento', '15F', ','): 1,
#              ('otorgar', 'garantías', 'personales'): 5,
#              ('de', 'ordeñe', ','): 1,
#              ('1', ')', 'Folio'): 2,
#              ('bienes', 'muebles', 'y'): 5,
#              ('Presidente', 'del', 'Directorio'): 186,
#              ('-', 'tración', 'de'): 1,
#              ('..-', 'SINDICATURA', ':'): 1,
#              (',', 'licenciado', 'administración'): 1,
#              ('Jessica', 'Mahara', 'Brecker'): 1,
#              ('22866416', ',', 'CUIT'): 1,
#              ('Presidente', ':', 'Ramiro'): 9,
#              ('.', 'Alem', '1110'): 3,
#              ('los', 'dos', 'incisos'): 1,
#              ('22', '.', '503'): 1,
#              ('1202', 'Romina', 'Carla'): 1,
#              ('exhibición', 'en', 'salas'): 1,
#              ('Vanina', 'PENNA', '.'): 1,
#              (',', 'teniendo', 'dedicación'): 1,
#              ('contraer', 'obligaciones', '.'): 17,
#              ('mandato', 'y', 'actuar'): 1,
#              ('mismos', 'y', 'la'): 4,
#              ('control', 'competentes', 'en'): 1,
#              ('Lote', '15', 'Fracción'): 1,
#              ('DNI', '18318052', ','): 1,
#              ('los', 'servicios', 'propios'): 7,
#              ('°', '13078', '/'): 1,
#              (',', 'sean', 'aéreas'): 1,
#              ('23', '.', '329'): 8,
#              ('anteriores', '.-', 'Capital'): 1,
#              ('°', '31820', '/'): 1,
#              ('Marcelo', 'DE', 'CARLI'): 2,
#              ('N', '°', '29350'): 1,
#              (':', 'Riglos', '177'): 1,
#              ('representaciones', 'relativos', 'a'): 1,
#              ('Simón', 'Alberto', 'PODROJSKY'): 2,
#              (',', 'mercadeo', ','): 3,
#              ('.-', 'Otorgar', 'fianzas'): 2,
#              ('13', '.', '873'): 2,
#              ('12', 'escribana', 'Roxana'): 1,
#              (':', 'Eduardo', 'Domingo'): 2,
#              ('711', '.', '866'): 1,
#              ('de', 'México', ','): 1,
#              ('en', 'los', 'dos'): 1,
#              ('López', 'Suriano', ','): 1,
#              ('-', '7', 'casado'): 2,
#              ('país', 'que', 'se'): 1,
#              ('Comercialización', ',', 'transporte'): 1,
#              ('y', 'especial', 'Sucre'): 1,
#              ('fijan', 'su', 'DOMICILIO'): 1,
#              ('ser', 'mandataria', '.-'): 1,
#              ('°', '44697', '/'): 1,
#              ('34', '.', '520'): 1,
#              ('y', 'al', 'Director'): 1,
#              ('(', 'aguas', ','): 1,
#              ('con', 'farmacia', ','): 1,
#              ('nº', '237', 'del'): 1,
#              ('o', 'activa', ','): 2,
#              ('los', 'casos', 'podrá'): 1,
#              ('o', 'asociaciones', 'deportivas'): 1,
#              ('para', 'eventos', ','): 5,
#              ('de', 'software', 'para'): 6,
#              ('27', '.', '067'): 1,
#              ('los', 'demás', 'rubros'): 1,
#              ('.', '421', ','): 7,
#              ('1366', ',', 'Beccar'): 1,
#              ('20', '-', '94952627'): 1,
#              (';', 'Paola', 'Marina'): 1,
#              ('de', 'la', 'Capital'): 10,
#              ('a', 'estos', ','): 3,
#              ('OBELISCO', 'INVERSIONES', 'Y'): 1,
#              ('seminarios', ',', 'conferencias'): 4,
#              ('.', 'Explotar', 'la'): 1,
#              ('DNI', '37609287', ','): 1,
#              ('fantasías', ',', 'anteojos'): 2,
#              ('20082667645', ',', 'Empresario'): 1,
#              (',', 'clínicas', ','): 15,
#              ('operaciones', 'sobre', 'inmuebles'): 58,
#              ('6to', 'departamento', 'L'): 1,
#              ('General', 'Pacheco', 'Tigre'): 1,
#              (',', 'cuentas', 'a'): 1,
#              (',', 'fleteros', ','): 1,
#              ('exportador', 'de', 'carnes'): 1,
#              ('condiciones', 'prescriptas', 'por'): 1,
#              ('jóvenes', 'o', 'adultos'): 2,
#              ('a', ')', 'CONSTRUCTORAS'): 3,
#              (',', 'Casada', ','): 1,
#              ('de', 'Cálculo', ','): 1,
#              ('domicilio', 'social', 'y'): 3,
#              ('Socios', ':', 'Ian'): 1,
#              ('Nº', '1555', 'de'): 1,
#              ('.', '942', ','): 1,
#              ('departamento', '54', 'y'): 2,
#              ('como', 'barrios', 'cerrados'): 2,
#              ('.', 'Falcke', 'Registro'): 1,
#              ('extranjero', 'la', 'fabricación'): 1,
#              ('software', '),', 'video'): 1,
#              ('o', 'asociados', 'con'): 3,
#              ('21', '.', '468'): 1,
#              (':', 'producir', ','): 1,
#              ('calle', 'Alazán', '345'): 1,
#              ('las', 'mismas', 'y'): 3,
#              ('Goñi', ';', 'los'): 1,
#              ('social', 'que', 'así'): 2,
#              ('operación', 'que', 'no'): 2,
#              ('en', 'Cavia', '3099'): 2,
#              ('Accionistas', ':', 'Angel'): 1,
#              ('Financieras', 'e', 'Inversoras'): 2,
#              (',', 'adquisiciones', 'del'): 1,
#              ('comunicación', 'que', 'se'): 1,
#              ('como', 'erróneamente', 'se'): 1,
#              ('la', 'Avenida', 'Martín'): 1,
#              ('e', 'infusiones', 'Compra'): 2,
#              ('folio', '1152', ','): 1,
#              ('de', 'Pratesi', '-'): 6,
#              ('pudiendo', 'procurar', 'asistencia'): 1,
#              ('de', 'atraques', '.'): 1,
#              ('a', 'la', 'gastronomia'): 1,
#              ('Piso', '12', ','): 6,
#              ('Agustin', 'Garzon', '3476'): 1,
#              ('PISO', '5º', ','): 1,
#              ('Eduardo', 'Sabater', '.'): 1,
#              ('5', ')', 'Tomar'): 1,
#              ('conforme', 'los', 'requisitos'): 2,
#              ('ganaderos', 'y', 'agroindustriales'): 1,
#              ('DNI', '7593295', ','): 1,
#              ('cierre', ':', '31'): 3,
#              (':', 'Paraná', '830'): 5,
#              ('2', ')', 'Comercialización'): 1,
#              ('Juan', 'María', 'DIBAR'): 1,
#              ('prestaciones', 'y', 'prácticas'): 1,
#              ('y', 'desarrollo', ';'): 1,
#              ('como', 'prestador', 'de'): 2,
#              ('Gabriel', 'DE', 'ORO'): 2,
#              ('una', ';', 'Tomás'): 1,
#              ('Maria', 'ABBRUZZI', ','): 1,
#              ('4342', 'C', '.'): 1,
#              ('.-', 'Los', 'dos'): 1,
#              (':', 'Juan', 'María'): 5,
#              ('ejercicio', 'y', 'hasta'): 1,
#              ('la', 'Sociedad', 'bajo'): 3,
#              ('T', '°:', '101'): 14,
#              ('Maximiliano', 'FERNÁNDEZ', ','): 2,
#              ('Manuel', 'Zappa', ','): 1,
#              ('”,', 'Puerto', 'Nuevo'): 2,
#              ('electrónicos', 'en', 'redes'): 1,
#              ('software', 'a', 'medida'): 5,
#              ('F', '°', '427'): 1,
#              ('acondicionado', ',', 'artefactos'): 1,
#              ('Autorizada', 'antes', 'citada'): 1,
#              ('fiduciante', ',', 'fiduciario'): 24,
#              ('climatización', ',', 'humidificación'): 1,
#              ('actividades', 'de', 'esparcimiento'): 2,
#              ('SOCIAL', ':', 'Olleros'): 1,
#              ('.', '903', '.'): 4,
#              ('21143042', '-', '8'): 1,
#              ('en', 'Pedro', 'Lozano'): 1,
#              ('asesoramiento', ',', 'instruccion'): 1,
#              (',', '“', 'web'): 1,
#              ('y', 'arrendamiento', 'de'): 19,
#              ('domiciliado', 'en', 'Amenabar'): 2,
#              ('de', 'artes', 'gráficas'): 1,
#              ('real', 'en', 'José'): 3,
#              ('843', ',', 'C'): 2,
#              ('07374582', '-', '9'): 1,
#              ('y', 'Reaseguros', 'en'): 1,
#              ('Roberto', 'Cayetano', 'Grosso'): 3,
#              ('16225836', '-', '3'): 1,
#              ('Herrero', 'de', 'Pratesi'): 6,
#              (')', 'Toda', 'las'): 1,
#              ('comunales', 'intercomunales', 'e'): 1,
#              ('Marcelo', 'Fabian', 'Lucio'): 2,
#              ('veterinario', ',', 'Alsina'): 1,
#              ('soporte', ',', 'respecto'): 3,
#              ('833', ',', 'CUIT'): 2,
#              ('registradas', 'para', 'cartera'): 10,
#              (',', 'realizando', 'en'): 1,
#              ('A', ';', 'Rubén'): 1,
#              ('elementos', 'del', 'hogar'): 1,
#              ('Ángel', 'Gallardo', '665'): 1,
#              ('7', ')', 'Prescinde'): 27,
#              ('al', 'servicio', 'y'): 1,
#              ('2195', 'el', '7'): 1,
#              ('de', 'Remedios', 'de'): 1,
#              ('como', 'puertos', 'y'): 1,
#              ('Directorio', ':', 'Sebastián'): 1,
#              ('55024', '/', '16'): 2,
#              ('24', '.', '791'): 1,
#              ('en', 'Paraná', '586'): 1,
#              ('actividad', 'sobre', 'toda'): 3,
#              ('RPC', ';', 'La'): 4,
#              ('directores', 'por', '3'): 50,
#              ('374', ',', 'Alianza'): 1,
#              ('3', ')', 'JUGAME'): 1,
#              (',', 'DNI', '26553297'): 1,
#              ('DNI', '22550658', ','): 1,
#              (',', 'y', 'ambos'): 1,
#              ('plenamente', 'con', 'su'): 1,
#              ('integral', 'en', 'materia'): 2,
#              ('industrialización', ',', 'almacenamiento'): 5,
#              ('Notarial', '1951', 'CABA'): 1,
#              ('ordinarias', 'o', 'preferidas'): 1,
#              (',', 'menaje', 'para'): 1,
#              ('personal', 'para', 'la'): 4,
#              (',', 'cableductos', 'y'): 1,
#              ('Mercedes', 'Amorena', ','): 1,
#              ('incluyendo', 'la', 'de'): 1,
#              ('compatibles', 'con', 'su'): 5,
#              ('44789', '/', '16'): 1,
#              ('aseo', 'y', 'confort'): 1,
#              ('Adrián', 'GOLBERG', ','): 1,
#              ('URCIUOLI', 'suscribe', '60'): 1,
#              ('funcionamiento', 'automático', ','): 1,
#              ('SOLAR', 'ISOLUX', 'CORSAN'): 4,
#              ('2016', 'Escribana', 'Natalia'): 1,
#              ('Concepción', 'Garcia', '–'): 1,
#              ('8', ',', 'del'): 4,
#              ('años', ',', 'Rioja'): 2,
#              ('tejidos', 'y', 'telas'): 1,
#              ('pagarés', ',', 'cheques'): 1,
#              (',', 'elaboración', 'e'): 1,
#              ('Inmobiliaria', ':', 'compra'): 6,
#              ('3', 'ejercicio', 'y'): 1,
#              ('AIRE', 'PURO', 'ARGENTINA'): 2,
#              ('34573128', '-', '3'): 1,
#              ('real', 'islas', 'Malvinas'): 1,
#              ('.', 'CONSTANTINI', ','): 1,
#              ('FINANCIERA', ':', 'i'): 1,
#              ('actuar', 'como', 'representante'): 2,
#              ('CABA', 'y', 'Juan'): 7,
#              ('alimentos', 'y', 'demás'): 1,
#              ('Manso', '1314', ','): 1,
#              ('1', '°,', 'Dto'): 6,
#              ('Funcional', '96', 'Pilar'): 1,
#              (':', '“', 'BOX'): 1,
#              ('asesor', 'de', 'marketing'): 1,
#              ('especificaciones', 'de', 'fábrica'): 3,
#              ('empresas', 'o', 'contratar'): 1,
#              ('BIASATTI', ',', 'los'): 1,
#              ('534', ',', 'empresario'): 3,
#              ('de', 'publicación', '14'): 97,
#              ('N', '°', '33201'): 1,
#              ('explotación', 'o', 'comercialización'): 2,
#              ('Social', ':', 'Isabel'): 1,
#              ('en', 'cumplimentando', 'con'): 1,
#              ('nacido', '3', '/'): 10,
#              ('a', ')', 'Logística'): 1,
#              ('20', '.', '005'): 2,
#              ('Griotti', ',', 'quienes'): 1,
#              ('bonos', ',', 'obligaciones'): 3,
#              ('artículos', 'de', 'jardinería'): 1,
#              ('Ensamble', ',', 'compra'): 1,
#              ('Scalabrini', 'Ortiz', '2673'): 3,
#              (';', 'plantas', 'industriales'): 1,
#              ('N', '°', '2739'): 1,
#              (':', 'Laura', 'Mariel'): 1,
#              ('los', 'actos', 'compatibles'): 4,
#              ('Víctor', 'Estevez', '.'): 1,
#              ('sus', 'partes', 'componentes'): 9,
#              ('vigentes', ',', 'determinados'): 2,
#              ('59', '.', '999'): 1,
#              ('realizar', 'asesoramiento', 'inmobiliario'): 1,
#              (',', 'personales', 'o'): 4,
#              (':', 'Tomer', 'AVNER'): 1,
#              ('Erasmo', 'número', '7'): 1,
#              ('y', 'cargo', '.'): 2,
#              ('apliquen', 'efectivamente', 'a'): 3,
#              ('Financieras', 'y', '/'): 1,
#              ('Claudio', 'Pasmanter', 'Becker'): 2,
#              ('para', 'líneas', 'de'): 1,
#              (';', 'griferías', 'y'): 1,
#              ('Clorinda', ',', 'Pilcomayo'): 1,
#              ('y', 'granja', ','): 2,
#              ('que', 'requiera', ','): 1,
#              ('.', '899', ';'): 1,
#              ('248', 'del', '06'): 1,
#              ('YUDCHAK', '.-', 'VICEPRESIDENTE'): 1,
#              (';', 'Giacomo', 'María'): 1,
#              ('Escritura', '20', '-'): 1,
#              ('pública', ',', 'opciones'): 1,
#              ('exportaciones', ',', 'instalar'): 1,
#              ('agua', ',', 'telecomunicaciones'): 3,
#              ('usuario', 'en', 'forma'): 2,
#              ('erróneamente', 'la', 'sede'): 1,
#              ('N', '°', '18871'): 1,
#              ('CARDOSO', 'autorizado', 'según'): 6,
#              ('flujo', 'de', 'información'): 1,
#              ('desarrolle', 'y', 'comercialice'): 2,
#              ('8', '/', '15'): 2,
#              ('festivales', 'artísticos', ','): 1,
#              ('representen', 'a', 'las'): 1,
#              ('tal', 'efecto', 'su'): 1,
#              ('alimenticios', ',', 'aditivos'): 1,
#              ('juguetes', ';', '6º'): 1,
#              ('PACASA', 'S', '.'): 2,
#              ('Gustavo', 'SEJUMIL', ','): 2,
#              ('.', '186', '.'): 2,
#              ('Social', ':', 'Correa'): 1,
#              ('236', ',', 'C'): 1,
#              ('venta', 'de', 'producciones'): 1,
#              ('síndicos', 'designados', 'constituyeron'): 1,
#              ('un', 'portal', 'de'): 1,
#              ('Los', 'socios', 'y'): 3,
#              ('N', '°', '19659'): 1,
#              ('52', ',', 'Barrio'): 1,
#              ('Guadalupe', 'Domínguez', ','): 1,
#              ('del', 'respectivo', 'país'): 6,
#              ('14038464', 'Palos', '551'): 1,
#              ('licencias', 'o', 'permisos'): 1,
#              ('no', 'tejidas', ','): 1,
#              ('6', 'Lote', '14'): 2,
#              ('4141', ',', 'CABA'): 1,
#              ('otro', 'material', 'vinculado'): 1,
#              (',', 'maquinarias', 'de'): 3,
#              ('l', ')', 'Jimena'): 1,
#              ('Suplente', ':', 'Norberto'): 7,
#              ('en', 'el', 'objeto'): 18,
#              ('Ben', 'HOLZSTEIN', ','): 1,
#              ('Ricardo', 'Gutierrez', '956'): 1,
#              ('Denominación', ':', 'Microconstrucciones'): 1,
#              ('Segurola', '4406', ','): 1,
#              ('km', '2', '.'): 1,
#              ('3053', ',', 'piso'): 2,
#              ('526', 'del', '22'): 1,
#              ('MINOLA', ',', 'nacida'): 1,
#              ('carteras', 'de', 'clientes'): 8,
#              ('FEUDO', ',', 'divorciada'): 1,
#              ('propia', 'o', 'para'): 4,
#              ('comercializar', 'en', 'cualquiera'): 3,
#              (',', 'auditoria', ','): 2,
#              ('B', '”,', 'y'): 1,
#              ('A', '.', 'El'): 9,
#              ('T', '°:', '67'): 16,
#              ('16', 'de', 'junio'): 2,
#              ('100', '.', '661'): 1,
#              ('transporte', 'aéreo', 'de'): 6,
#              ('1934', ',', 'DNI'): 1,
#              ('Cierre', '31', 'de'): 4,
#              ('piso', 'depto', 'B'): 2,
#              ('llenas', 'o', 'rellenadas'): 1,
#              ('Marquez', 'y', 'Directora'): 1,
#              ('78', 'de', 'Sociedades'): 2,
#              ('reemplazar', ',', 'ya'): 1,
#              ('Court', ',', 'Flat'): 1,
#              ('del', 'artículo', '5'): 1,
#              ('hormigón', 'vibrado', ','): 1,
#              ('y', 'Romina', 'Daniela'): 1,
#              (',', 'edificios', 'públicos'): 4,
#              ('tanto', 'en', 'forma'): 3,
#              ('709', '.', '607'): 1,
#              ('Carlos', 'An', '-'): 1,
#              ('y', 'casados', '2'): 3,
#              ('a', 'esas', 'actividades'): 2,
#              ('obras', 'teatrales', ','): 2,
#              (',', 'Stella', 'Maris'): 2,
#              ('posible', 'de', 'las'): 2,
#              ('Herrera', '568', ','): 1,
#              ('-', '71033962', '-'): 1,
#              ('043', '.', '620'): 1,
#              ('el', 'área', 'informática'): 1,
#              ('844', '.', '586'): 1,
#              ('CACERES', ',', 'casada'): 1,
#              ('-', '93264308', '-'): 1,
#              ('o', 'computación', 'y'): 1,
#              ('titular', 'autorizada', 'en'): 1,
#              ('°', '59013', '/'): 1,
#              ('aduana', 'y', 'reglamentos'): 2,
#              ('03', '/', '73'): 6,
#              ('-', '28985043', '-'): 1,
#              ('2016', ',', 'Lucila'): 1,
#              (',', 'custodias', 'y'): 5,
#              (',', 'científicas', ','): 2,
#              ('Catalina', 'lote', '502'): 1,
#              ('veintisiete', 'Javier', 'Ickowicz'): 1,
#              ('Cayetano', 'MONACO', ','): 1,
#              ('la', 'Escribana', 'citada'): 2,
#              ('dictámenes', 'e', 'investigaciones'): 1,
#              ('personas', 'con', 'titulo'): 2,
#              ('Villaflor', '350', 'piso'): 2,
#              ('nupcias', 'con', 'Zhang'): 1,
#              (',', 'y', 'exportador'): 1,
#              ('libre', 'disponibilidad', 'de'): 1,
#              ('industria', 'del', 'petróleo'): 3,
#              (',', 'dicorciado', ','): 1,
#              ('y', 'el', 'cumplimiento'): 4,
#              ('Maximiliano', 'Stegmann', '-'): 16,
#              ('ALTOS', 'VUELOS', 'CORDOBA'): 2,
#              ('¬', 'trica', ','): 1,
#              ('GARANTÍAS', ':', 'Asimismo'): 1,
#              ('certificados', 'de', 'participación'): 7,
#              ('58626', '/', '16'): 1,
#              ('812', ',', 'Planta'): 1,
#              ('/', 'u', 'obras'): 1,
#              ('DE', 'REDES', 'ELECTRÓNICAS'): 2,
#              ('casada', ',', 'Los'): 1,
#              ('30594267', ',', 'CUIT'): 1,
#              ('presente', 'objeto', ','): 3,
#              ('forma', 'abierta', 'y'): 1,
#              ('generadas', 'en', 'forma'): 19,
#              ('otros', 'elementos', 'arquitectónicos'): 1,
#              ('CAPITAL', '$', '150000'): 1,
#              ('41202', '/', '16'): 1,
#              ('COMPRA', 'Y', 'VENTA'): 2,
#              ('20', '-', '21429750'): 1,
#              ('10', 'años', '6'): 1,
#              ('que', 'posean', 'los'): 1,
#              ('titular', 'y', 'Presidente'): 10,
#              ('y', 'juegos', 'electromecánicos'): 1,
#              ('DNI', '20195832', ','): 1,
#              (')', 'Bartolo', 'Espósito'): 1,
#              ('especie', ';', 'servicios'): 1,
#              ('años', 'desde', 'su'): 191,
#              ('SPINETTO', ',', 'argentino'): 1,
#              ('5', ')', 'Compraventa'): 1,
#              ('directa', 'o', 'a'): 9,
#              ('°', 'oficina', '1'): 1,
#              ('-', 'line', 'y'): 1,
#              ('5218', 'CABA', '.'): 1,
#              ('formas', 'y', '/'): 2,
#              ('3440', 'CABA', ';'): 1,
#              ('profesionales', 'legalmente', 'habilitados'): 3,
#              ('716', ',', 'domicilio'): 1,
#              ('22', '/', '03'): 67,
#              (',', 'en', 'centros'): 1,
#              (':', 'JUAN', 'FATO'): 1,
#              ('1767', ',', 'PB'): 2,
#              ('Depto', '5', ','): 1,
#              ('servicios', ',', 'servicio'): 2,
#              ('domiciliada', 'en', 'Salvador'): 1,
#              ('presidente', 'a', 'María'): 1,
#              ('Daniel', 'MARTINEZ', 'FONT'): 1,
#              ('registrables', ',', 'semovientes'): 1,
#              ('apoyo', 'y', 'contención'): 1,
#              ('proveedor', 'del', 'estado'): 1,
#              ('Agote', '1850', 'Ranelagh'): 1,
#              ('Victoria', 'Argimon', '.'): 1,
#              ('HARRIET', ',', 'argentina'): 1,
#              ('Libertador', '5442', 'Piso'): 2,
#              ('10', '/', '97'): 3,
#              ('o', 'sin', 'equipos'): 1,
#              ('A', ',', 'argentinos'): 1,
#              ('2', 'departamento', '“'): 2,
#              ('de', '1955', ','): 2,
#              ('fluvial', 'y', '/'): 1,
#              (';', 'Pablo', 'ROBERT'): 1,
#              ('con', 'relación', 'al'): 4,
#              ('Pino', '1739', ','): 1,
#              (':', 'MILLING', 'S'): 1,
#              ('RED', 'S', '.'): 2,
#              ('en', 'Los', 'Algarrobos'): 1,
#              ('parrilla', ',', 'casa'): 1,
#              ('real', 'en', 'Riobamba'): 1,
#              ('Velez', '4924', ','): 1,
#              ('Matrícula', ':', '5213'): 5,
#              ('nacido', 'el', 'veintinueve'): 1,
#              ('o', 'complementos', 'para'): 2,
#              ('relacionado', 'con', 'Internet'): 1,
#              ('404', ',', 'domiciliado'): 1,
#              ('CABA', ',', 'Serenella'): 1,
#              ('internación', ',', 'asistencia'): 1,
#              ('Alejandro', 'ROJAS', ','): 1,
#              ('no', 'esté', 'expresamente'): 1,
#              ('/', '78', ','): 57,
#              ('58', 'F', '288'): 1,
#              ('que', 'los', 'Asesoramientos'): 1,
#              ('Arcos', '1969', 'piso'): 1,
#              ('10', ')', 'Tonelero'): 1,
#              ('Deymonnaz', ',', 'Registro'): 2,
#              ('funcionamiento', ',', 'prestar'): 1,
#              ('país', ',', 'las'): 25,
#              ('sociedad', ':', 'Presidente'): 2,
#              (';', 'Mariano', 'Augusto'): 1,
#              ('.', '627', '.'): 3,
#              ('tres', 'periodos', '.'): 1,
#              ('guardan', ',', 'en'): 1,
#              ('billetes', 'extranjeros', ','): 2,
#              (',', 'por', 'representantes'): 1,
#              ('El', 'transporte', 'de'): 1,
#              ('fletes', 'y', 'liquidación'): 1,
#              ('29660', '/', '16'): 1,
#              ('Redonnet', 'y', 'Wilensky'): 4,
#              ('Alvear', '4496', 'Lanus'): 2,
#              ('promoción', 'de', 'exposiciones'): 1,
#              ('representación', 'legal', 'y'): 4,
#              ('000', '.-', 'Federico'): 1,
#              ('Iparraguirre', ',', 'argentina'): 1,
#              ('Realizar', 'operaciones', 'de'): 16,
#              ('1661', 'Piso', '5'): 2,
#              ('el', '02', 'de'): 2,
#              ('mediante', 'la', 'suscripción'): 3,
#              (',', 'regentear', 'carteras'): 1,
#              (',', 'al', 'folio'): 12,
#              ('de', 'redes', 'cloacales'): 1,
#              ('material', 'fijo', 'blindado'): 1,
#              ('a', 'sus', 'cargos'): 1,
#              ('Bautista', 'Alberdi', '7258'): 2,
#              ('C', '.', 'V'): 1,
#              ('N', '°', '21673'): 1,
#              ('Fiorella', 'Molinari', 'casada'): 1,
#              ('o', 'ejercer', 'representaciones'): 2,
#              ('mantenimiento', 'del', 'equipamiento'): 1,
#              ('primaria', 'en', 'todas'): 1,
#              ('Antonio', 'MANZANELLI', ','): 2,
#              ('procedimientos', 'de', 'selección'): 1,
#              ('N', '”,', 'CABA'): 3,
#              ('Nº', '1107', 'Johanna'): 2,
#              ('cargos', 'fijan', 'domicilio'): 2,
#              ('inscripción', ';', 'Capital'): 1,
#              ('en', 'Dorrego', '1940'): 1,
#              ('Sebastián', 'ARES', ','): 1,
#              ('Inmobiliaria', ':', 'La'): 4,
#              ('debidamente', 'matriculados', '.-'): 3,
#              ('16', 'se', 'omitio'): 1,
#              ('bebidas', 'elaborados', 'y'): 2,
#              ('o', 'que', 'sirvan'): 1,
#              ('b', ')', 'Asistir'): 1,
#              ('Norma', 'LOPEZ', ','): 1,
#              ('adjudicaciones', 'relacionadas', 'al'): 1,
#              ('WEB', ',', 'y'): 1,
#              ('argentinos', 'por', 'tres'): 1,
#              ('incluso', 'inmobiliarias', 'y'): 1,
#              ('Público', 'bajo', 'el'): 1,
#              ('“', 'EVOLUTION', 'TECHNOLOGY'): 1,
#              ('Pardo', '13', '/'): 1,
#              ('de', 'Septiembre', '546'): 1,
#              ('Nº', '504', 'de'): 2,
#              ('Silva', ',', '26'): 1,
#              ('485', 'de', 'fecha'): 2,
#              ('ALONSO', ',', 'DIRECTOR'): 1,
#              ('Tomás', 'Balmayor', '-'): 1,
#              ('mandatos', 'representaciones', 'consignaciones'): 1,
#              ('Consultoria', 'de', 'sistemas'): 1,
#              ('“', 'RÓMULO', 'NAON'): 1,
#              ('Diego', 'MAZER', ','): 1,
#              ('944', ',', '11'): 1,
#              ('Graciela', 'Noemí', 'DEL'): 1,
#              ('263', '.', '425'): 1,
#              ('de', 'Bogotá', ','): 1,
#              ('732', '.', '365'): 1,
#              ('Internet', ';', '('): 1,
#              (',', 'escoltas', 'y'): 1,
#              ('años', 'Autorizado', 'según'): 3,
#              ('277', 'del', '28'): 1,
#              ('a', 'las', 'normativas'): 1,
#              ('gestión', 'necesaria', 'para'): 1,
#              ('pública', 'Nº', '48'): 1,
#              ('Financieras', 'o', 'cualquiera'): 2,
#              ('infraestructura', 'propia', ','): 1,
#              ('512', ')', 'de'): 1,
#              ('2070', 'de', 'Capital'): 2,
#              ('Vicente', 'Truffa', ','): 1,
#              (':', '2', 'de'): 1,
#              ('MAZZOCCHI', ':', 'y'): 1,
#              ('la', 'República', 'de'): 6,
#              ('y', 'de', 'estimulación'): 1,
#              ('-', '17513209', '-'): 1,
#              ('exigible', ',', 'o'): 1,
#              ('incisos', 'precedentes', '.'): 5,
#              ('7', '.', '344'): 1,
#              ('–', 'y', 'contratación'): 1,
#              ('terrestres', ',', 'helicópteros'): 1,
#              ('3352', ',', '3º'): 1,
#              ('11', ',', 'número'): 1,
#              ('°', '57532', '/'): 1,
#              ('suplente', ':', 'David'): 1,
#              (':', '3820', 'C'): 3,
#              ('Federico', 'Iván', 'Salcedo'): 1,
#              ('6º', 'Piso', 'Depto'): 1,
#              ('Rosato', 'quienes', 'aceptan'): 1,
#              ('Suplente', 'María', 'Sol'): 1,
#              ('podrá', 'utilizar', 'todos'): 2,
#              ('equipos', 'de', 'internet'): 1,
#              ('FUNES', 'S', '.'): 1,
#              ('y', 'todo', 'sus'): 1,
#              ('Daniel', 'FERRARO', '.'): 1,
#              ('04294282', '-', '1'): 1,
#              ('helados', ',', 'y'): 1,
#              ('Barbosa', 'Moyano', ','): 1,
#              ('3', ',', 'Departamento'): 7,
#              ('DE', 'JUNIO', '9'): 1,
#              ('985', ',', 'domiciliado'): 1,
#              ('vez', 'actuar', 'como'): 1,
#              ('argentinos', 'CABA', '2'): 2,
#              (';', 'Angel', 'Cruz'): 2,
#              ('12442', '/', '16'): 1,
#              ('N', '°', '12911'): 1,
#              ('3765', ',', 'Piso'): 1,
#              ('N', '°', '6246'): 1,
#              (',', 'Amanda', 'Margarita'): 1,
#              ('artísticas', 'o', 'de'): 1,
#              ('exportar', 'mercaderías', 'derivadas'): 1,
#              ('de', 'fecha', '28'): 102,
#              ('derivadas', 'de', 'ilícitos'): 1,
#              ('Diciembre', 'de', '1970'): 1,
#              ('de', 'un', 'punto'): 1,
#              ('DEL', 'INCISO', 'ANTERIOR'): 1,
#              ('o', 'recurrentes', ','): 1,
#              ('°:', '94', 'C'): 3,
#              (',', 'del', '3'): 4,
#              ('Ejecución', ',', 'proyectos'): 1,
#              ('integren', ';', 'y'): 1,
#              ('Longchamps', 'y', 'Agustín'): 1,
#              ('.', 'Duración', 'es'): 1,
#              ('1824', ',', 'CABA'): 2,
#              ('aceptaron', 'cargos', 'y'): 9,
#              ('Aires', ';', 'Griselda'): 1,
#              ('el', 'futuro', 'y'): 7,
#              ('propios', 'o', 'integrales'): 3,
#              ('fecha', '30', 'de'): 1,
#              ('20', '-', '39770807'): 1,
#              (';', 'Síndicos', 'Suplentes'): 8,
#              ('y', 'una', 'acción'): 1,
#              (',', 'operaciones', 'sobre'): 4,
#              ('socio', 'Lin', 'Xiaodong'): 2,
#              ('fabricación', 'de', 'vajilla'): 1,
#              ('fideicomisos', 'financieros', 'con'): 2,
#              (',', 'flejes', ','): 1,
#              ('en', 'el', 'uso'): 2,
#              ('las', 'leyes', 'que'): 10,
#              ('demás', 'productos', 'destinados'): 1,
#              ('que', 'durarán', 'en'): 1,
#              ('del', 'Libertador', '7270'): 2,
#              ('N', '°', '1198'): 1,
#              ('4', '.', '981'): 2,
#              ('127', ',', 'piso'): 3,
#              ('o', 'supervisión', 'de'): 1,
#              ('coticen', 'o', 'no'): 1,
#              ('Pablo', 'German', 'Lorenzo'): 3,
#              (':', 'Clara', 'María'): 1,
#              ('Nº', '254', 'del'): 2,
#              ('043', '.', '814'): 1,
#              ('han', 'constituido', 'la'): 12,
#              ('Gutierrez', '2545', 'piso'): 1,
#              ('o', 'marítima', ';'): 2,
#              ('ACCONCIA', ',', 'Suscribe'): 1,
#              ('6', ',', 'casado'): 20,
#              ('Eugenia', 'Pescarmona', ';'): 1,
#              ('y', 'terciaria', ';'): 1,
#              ('N', '°', '180532'): 2,
#              ('N', '°', '177247'): 1,
#              ('forrajes', ',', 'granos'): 1,
#              ('sólidos', 'y', 'gases'): 1,
#              ('384', '.', '103'): 1,
#              ('individuos', 'o', 'empresas'): 1,
#              ('en', 'Conesa', '2171'): 1,
#              ('Anonima', 'se', 'constituye'): 2,
#              ('5281', 'C', '.'): 3,
#              ('Mercedes', 'Ibañez', 'autorizada'): 2,
#              ('Gestionar', 'y', '/'): 1,
#              ('Oriente', ',', 'Luciano'): 1,
#              ('comercialización', ',', 'inportación'): 1,
#              ('como', 'los', 'que'): 2,
#              ('repostería', ',', 'artículos'): 1,
#              (':', '“', 'EMUVIAL'): 1,
#              ('Hugo', 'MAGARZO', ','): 2,
#              ('Y', 'PRESIDENTE', 'Paula'): 1,
#              ('de', 'conciertos', ','): 2,
#              ('con', ',', 'complementarios'): 1,
#              (',', 'mientras', 'la'): 4,
#              ('Verónica', 'Iampolsky', '.'): 1,
#              ('Escritura', '21', '6'): 1,
#              ('3802', ',', 'Olivos'): 1,
#              ('06', '7', ')'): 2,
#              (',', 'las', 'redes'): 1,
#              ('687', '.', '886'): 1,
#              ('Ulises', 'Merlan', ','): 1,
#              ('Melina', 'TORTORELLA', ','): 1,
#              ('cría', 'engorde', 'e'): 1,
#              (':', 'Ivan', 'Diego'): 1,
#              ('toda', 'otra', 'presentación'): 4,
#              ('actividad', 'descripta', 'en'): 5,
#              ('la', 'colocación', 'de'): 6,
#              ('1979', ',', 'comerciante'): 4,
#              ('25427', '/', '16'): 1,
#              ('722', 'CUIT', '20'): 2,
#              ('Aadministración', ':', 'Directorio'): 1,
#              ('aceptación', 'de', 'mandatos'): 2,
#              ('terminación', ',', 'mezcla'): 1,
#              ('comunicarse', 'entre', 'sí'): 1,
#              ('como', 'socia', 'de'): 3,
#              ('sanatorios', ',', 'establecimientos'): 1,
#              ('que', 'incluya', 'el'): 1,
#              ('extracción', 'de', 'aceite'): 1,
#              ('69', ',', 'Avellaneda'): 1,
#              ('Por', 'escritura', '217'): 1,
#              ('SONIDO', ',', 'VIDEO'): 1,
#              ('y', 'coordine', 'sus'): 1,
#              (',', 'alojamiento', 'en'): 2,
#              ('naturales', 'renovables', ','): 1,
#              ('“', 'INVERSORA', 'IMESOL'): 1,
#              ('GESTION', 'YA', 'S'): 3,
#              ('PISO', '13', 'C'): 4,
#              ('ejercer', 'representaciones', 'y'): 6,
#              ('-,', 'propios', 'y'): 1,
#              ('Agente', 'de', 'administración'): 1,
#              ('y', 'telemarketing', 'y'): 1,
#              ('Pablo', 'Valente', ','): 1,
#              ('14', '(', 'bahía'): 1,
#              ('el', 'petróleo', ')'): 5,
#              ('equipamiento', ',', 'hardware'): 1,
#              ('INSTITUTO', 'GROWING', 'S'): 2,
#              ('-', '21475727', '-'): 1,
#              ('Gerardo', 'Matías', 'RATTO'): 1,
#              ('sede', ';', 'Cierre'): 1,
#              ('4', '-', 'La'): 1,
#              ('e', ')', 'FINANCIERA'): 1,
#              ('Lucio', 'ANGELOTTI', '.'): 1,
#              ('Escritura', 'número', '28'): 1,
#              ('iii', ')', 'prestación'): 1,
#              ('indirectamente', 'en', 'procesos'): 1,
#              ('desarrollar', ',', 'en'): 1,
#              ('sociedades', ',', 'con'): 1,
#              ('terceros', ',', 'operaciones'): 1,
#              ('artículos', 'conexos', '.'): 1,
#              ('187', 'Registro', 'Notarial'): 1,
#              (',', 'nombres', 'comerciales'): 3,
#              ('íntegramente', 'en', 'acciones'): 2,
#              ('real', 'Boulevard', 'Azucena'): 1,
#              ('Luis', 'Viale', '2770'): 1,
#              ('real', 'Laguna', '769'): 1,
#              ('y', 'desagüe', ','): 1,
#              ('o', 'públicas', 'en'): 1,
#              ('materia', ',', 'hayan'): 1,
#              ('y', 'cabaña', ','): 1,
#              ('calle', 'Llavallol', '3837'): 1,
#              ('de', 'viviendas', 'para'): 1,
#              ('independientes', '.-', 'Cierre'): 2,
#              ('°', '52919', '/'): 1,
#              ('CONSTE', '.-', 'Autorizado'): 1,
#              ('proyecciones', 'cinematográficas', 'con'): 1,
#              (',', 'asesoría', 'y'): 6,
#              ('provisión', 'y', '/'): 1,
#              (')', 'Asesoramiento', ','): 6,
#              ('del', 'número', 'de'): 33,
#              ('diferentes', 'servicios', 'y'): 1,
#              ('Fiscalización', ':', 'mismos'): 4,
#              ('vitivinícolas', ',', 'hortícolas'): 6,
#              ('material', 'filmico', 'y'): 1,
#              ...})

# %%
countMenosUn
# Out:
# defaultdict(int,
#             {('número', '1008'): 1,
#              ('Antequera', '3745'): 1,
#              ('Quintana', '478'): 1,
#              ('Gassino', '-'): 2,
#              ('8', 'y'): 7,
#              ('con', 'viajes'): 1,
#              ('repostería', ','): 6,
#              ('gasífera', 'y'): 3,
#              ('Concesiones', ':'): 1,
#              ('“', 'LORD'): 1,
#              ('accionista', 'y'): 1,
#              ('sociedad', 'ejercida'): 1,
#              ('Patricia', 'Monica'): 5,
#              ('o', 'desguace'): 1,
#              (':', '3976'): 1,
#              ('24053927', ','): 2,
#              ('numero', '550'): 1,
#              ('Félix', 'Arturo'): 1,
#              ('Enrique', 'César'): 2,
#              ('Maris', 'Marengo'): 1,
#              ('1799', 'CABA'): 1,
#              ('FISCHMAN', ','): 2,
#              ('LABARDEN', 'AG'): 2,
#              ('reg', '.'): 48,
#              ('8487', '/'): 1,
#              ('3041', ','): 4,
#              ('el', 'vicepresidente'): 10,
#              ('ellos', 'inmuebles'): 3,
#              ('Especial', ','): 3,
#              ('MABEL', 'MONTEVERDE'): 1,
#              ('comida', 'elaboradas'): 1,
#              ('Guirotane', ','): 1,
#              ('aquél', 'y'): 1,
#              ('comercialización', 'así'): 4,
#              ('Sarmiento', '4913'): 1,
#              (',', 'facturación'): 6,
#              ('Darío', 'BRITEZ'): 4,
#              ('ceros', '.'): 1,
#              ('electrónicos', 'y'): 26,
#              ('silos', 'y'): 3,
#              ('38498237', '-'): 2,
#              ('velocidad', ','): 1,
#              ('3389', 'DANIEL'): 1,
#              ('LC', '6530579'): 1,
#              ('CAVANAGH', 'MARQUES'): 2,
#              ('de', 'urgencia'): 2,
#              ('$', '100000'): 168,
#              ('-', '17686797'): 1,
#              ('URBANARQ', 'S'): 2,
#              ('superiores', 'sean'): 1,
#              ('en', 'Álvarez'): 2,
#              ('11', 'Dpto'): 1,
#              ('Escritura', '3'): 4,
#              ('23669839', 'comerci'): 1,
#              ('Maria', 'Valenti'): 1,
#              ('2015', 'registro'): 1,
#              ('Nº', '1374'): 1,
#              ('lo', 'autorizados'): 1,
#              ('y', 'enseñanza'): 1,
#              ('geoposicionamiento', 'y'): 1,
#              ('951', 'piso'): 2,
#              ('la', 'competitividad'): 1,
#              ('centrales', 'para'): 1,
#              ('al', 'Régimen'): 9,
#              ('Adriana', 'Galazzi'): 1,
#              ('Sistemas', 'para'): 1,
#              (':', 'Cultivo'): 1,
#              ('Lote', '52'): 1,
#              ('o', 'urbanas'): 2,
#              ('21717', '/'): 1,
#              ('Obras', 'de'): 6,
#              ('que', 'desplieguen'): 1,
#              ('862', 'de'): 1,
#              ('Fabián', 'ZUKER'): 1,
#              ('7868', '/'): 1,
#              ('Nº', '1004'): 1,
#              ('respectivos', '.'): 10,
#              ('repasadores', ','): 1,
#              ('CARLOS', 'COPELLO'): 2,
#              ('202', 'C'): 1,
#              (':', 'Desarrollar'): 6,
#              ('Moreno', '520'): 1,
#              ('Primero', 'de'): 1,
#              ('°', '15611'): 1,
#              (';', 'llevar'): 1,
#              (',', 'media'): 22,
#              ('hubiese', 'designado'): 3,
#              ('patentes', 'y'): 16,
#              ('Contratación', 'y'): 4,
#              ('las', 'transitorias'): 1,
#              ('Giesen', '.-'): 1,
#              ('SOTOMAYOR', ','): 3,
#              ('-', '35728260'): 1,
#              (':', '5403'): 1,
#              (':', '3555'): 1,
#              (')', '$'): 819,
#              ('Gutiérrez', '1896'): 1,
#              ('Ocupacional', ','): 1,
#              ('39522', '/'): 1,
#              ('De', 'Franco'): 2,
#              ('Mauro', 'Giordano'): 1,
#              ('TI', '29860'): 1,
#              ('otros', 'ya'): 1,
#              ('personales', 'otorgados'): 1,
#              ('TABACH', ','): 1,
#              (',', 'debentures'): 113,
#              ('Le', 'Parc'): 1,
#              ('Orlando', 'Tapia'): 2,
#              ('cosechas', ','): 6,
#              ('8233', '/'): 1,
#              ('Woon', 'Tae'): 2,
#              ('8', 'KM'): 1,
#              ('al', 'turismo'): 3,
#              ('CORRALON', 'S'): 1,
#              ('HARTRODT', 'CHILE'): 1,
#              ('ACCION', 'S'): 2,
#              ('1511', 'Piso'): 1,
#              ('°', '52948'): 1,
#              ('incluyan', 'el'): 2,
#              ('22547176', '-'): 2,
#              (',', 'guatemalteco'): 1,
#              (')', '11'): 17,
#              ('estampado', ','): 5,
#              ('Brasil', '2335'): 1,
#              ('Julián', 'MILD'): 1,
#              ('Suplente', 'por'): 1,
#              ('del', 'directorio'): 63,
#              ('IMÁGENES', ','): 1,
#              ('Ejecución', 'de'): 11,
#              ('Esc', '9'): 2,
#              ('Ley', 'número'): 3,
#              ('y', 'Norman'): 4,
#              ('2328', 'S'): 1,
#              ('.', '399'): 6,
#              ('.', 'Justo'): 18,
#              (',', 'Matias'): 2,
#              ('de', '1989'): 5,
#              ('Vehículos', 'automóviles'): 1,
#              ('415', 'DE'): 1,
#              ('calle', 'Iberá'): 3,
#              ('Erico', 'HEIMANN'): 2,
#              ('extinción', 'automática'): 1,
#              ('2771', 'piso'): 1,
#              ('1009', 'de'): 1,
#              ('domiciliado', 'Superí'): 1,
#              (',', 'Cobo'): 1,
#              ('año', 'Sede'): 1,
#              ('Asimismo', 'la'): 8,
#              ('correctivo', 'en'): 2,
#              ('.:', '36571'): 1,
#              ('su', 'mandato'): 2,
#              ('Arougetti', 'nacida'): 1,
#              ('completando', 'todo'): 2,
#              (',', 'inventados'): 3,
#              (':', '3904'): 1,
#              ('Nº', ':'): 10,
#              ('11499556', '-'): 1,
#              ('correlativo', '1699214'): 1,
#              ('Heras', '2949'): 2,
#              ('Martín', 'VIDAL'): 1,
#              ('graniferas', ','): 1,
#              (',', 'bulones'): 1,
#              ('un', 'fin'): 1,
#              (')', 'Nélida'): 1,
#              ('Juan', 'Guillermo'): 2,
#              ('comisión', 'consignación'): 2,
#              ('pacientes', 'particulares'): 3,
#              ('GASTIABURO', ','): 1,
#              ('Nº', '1432'): 1,
#              ('comisiones', 'vinculados'): 4,
#              ('publicación', '28'): 89,
#              ('°:', '344'): 20,
#              ('Zoppi', '-'): 3,
#              ('13330', '/'): 1,
#              ('Fº', '215'): 1,
#              ('muebles', 'de'): 1,
#              ('tengan', 'títulos'): 1,
#              ('fríos', ','): 1,
#              ('Nestor', 'Acosta'): 1,
#              ('.', '782'): 8,
#              ('Kirschmann', '-'): 6,
#              ('efectivamente', 'a'): 3,
#              ('1328', ','): 1,
#              ('se', 'constituye'): 33,
#              ('ERDESK', 'S'): 1,
#              ('°', '61408'): 1,
#              ('soltero', 'empleado'): 2,
#              ('para', 'actividades'): 1,
#              ('2174', 'Luciana'): 3,
#              ('Obras', 'y'): 2,
#              ('se', 'vincule'): 22,
#              ('puede', 'realizar'): 9,
#              ('Montevideo', '1618'): 1,
#              ('Azcuénaga', '245'): 6,
#              ('C', '574108'): 1,
#              ('fojas', '28691'): 1,
#              ('reglamenten', 'algunas'): 1,
#              ('mandatos', 'Mediante'): 1,
#              ('Adrian', 'MIRCOVICH'): 2,
#              (',', 'entes'): 8,
#              ('y', 'financiero'): 9,
#              ('.', 'G'): 63,
#              ('-', '94107599'): 1,
#              ('Anoni', '.'): 1,
#              ('Ezequiel', 'ROSALES'): 2,
#              ('Shu', 'Un'): 2,
#              ('derecha', ','): 2,
#              ('y', 'Alejo'): 4,
#              ('capitales', 'para'): 5,
#              (':', 'Ramírez'): 1,
#              ('Registro', '73'): 2,
#              ('Soltera', 'Sanabria'): 1,
#              ('188', 'de'): 10,
#              ('166', '.'): 7,
#              (',', 'reintegros'): 2,
#              ('Departamento', 'Letra'): 1,
#              ('2035', 'Silvina'): 1,
#              ('3024', ';'): 1,
#              ('Feldman', 'Vert'): 1,
#              (',', 'tradicionalmente'): 1,
#              ('Hernán', 'Celorrio'): 2,
#              ('eventos', 'vinculados'): 2,
#              ('adscripto', 'al'): 3,
#              ('14', 'San'): 2,
#              ('358', ','): 4,
#              ('255', '.'): 1,
#              (')', 'Eliana'): 2,
#              ('2016', 'Mariana'): 1,
#              ('concertación', 'entre'): 1,
#              ('actividades', 'no'): 1,
#              (',', 'refrigerios'): 1,
#              ('lacado', 'de'): 1,
#              ('naturalizada', ','): 4,
#              ('José', 'SBARBI'): 10,
#              ('sin', 'suministro'): 2,
#              ('22680', '/'): 1,
#              ('indirectamente', '.'): 1,
#              (',', 'espolvoreó'): 1,
#              ('24', 'número'): 1,
#              ('.', '264'): 9,
#              ('20864', '/'): 1,
#              ('Alarico', 'Rosendo'): 1,
#              ('Magdalena', 'KUDRNAC'): 1,
#              ('de', 'adjudicataria'): 1,
#              (',', 'Tuyucue'): 1,
#              ('Ombú', '3812'): 2,
#              ('21673', '/'): 1,
#              ('MATALON', ','): 1,
#              ('537', 'Piso'): 8,
#              ('despacho', '.'): 1,
#              ('remolques', ','): 1,
#              ('LAS', 'MENCIONADAS'): 1,
#              ('6363', ','): 2,
#              (',', 'Capitán'): 2,
#              ('aquellos', ';'): 1,
#              ('9601', '/'): 1,
#              ('habilitante', 'contratados'): 10,
#              (',', 'Complejo'): 1,
#              ('27389', '/'): 1,
#              ('.', '128'): 12,
#              (')', 'MURILLO'): 1,
#              ('Pamela', 'Yñiquez'): 2,
#              ('en', 'Otamendi'): 2,
#              (',', 'IMPORTACION'): 2,
#              ('líneas', ','): 2,
#              ('domiciliado', 'Piedras'): 1,
#              ('actividades', 'las'): 4,
#              ('jarabes', 'y'): 2,
#              (',', 'Sr'): 1,
#              ('lo', 'hubiere'): 6,
#              ('17151', '/'): 1,
#              ('naturaleza', 'civil'): 6,
#              ('Paz', '3493'): 1,
#              ('explotar', 'salas'): 1,
#              ('tecnología', 'especialmente'): 1,
#              ('548', 'C'): 4,
#              ('y', 'máquina'): 1,
#              (';', 'SEDE'): 4,
#              ('Palacios', 'María'): 2,
#              ('referidos', ','): 2,
#              ('(', 'con'): 4,
#              ('en', 'Fournier'): 2,
#              ('Escritura', '259'): 1,
#              ('Rosas', ','): 1,
#              ('Comprende', 'todo'): 1,
#              ('Pacheco', '2968'): 1,
#              ('Jorge', 'ALBANI'): 2,
#              ('-', '30282881'): 1,
#              ('804', '.'): 5,
#              ('°', '8854'): 1,
#              ('sociales', 'comedores'): 1,
#              ('Gaudiosi', 'Director'): 1,
#              ('4220', '/'): 1,
#              ('La', 'Tranquera'): 1,
#              ('°', '22673'): 1,
#              ('Horacio', 'Polivik'): 1,
#              ('°', '50622'): 1,
#              ('Nº', '262'): 1,
#              ('o', 'cocheras'): 2,
#              ('Wilde', 'Partido'): 1,
#              ('de', 'ligas'): 1,
#              ('Villalba', ','): 1,
#              ('de', 'Formosa'): 1,
#              ('isotipos', ';'): 1,
#              ('Emitir', 'certificados'): 1,
#              ('de', 'agente'): 2,
#              ('4020', 'C'): 2,
#              ('Esteves', 'Sagui'): 2,
#              ('San', 'Fernando'): 47,
#              ('22890490', ','): 1,
#              ('las', 'garantí'): 1,
#              ('de', 'artículos'): 159,
#              ('Juárez', '6017'): 1,
#              ('Libertad', '736'): 1,
#              ('o', 'descargados'): 1,
#              ('Margall', ','): 1,
#              ('Oficina', 'K'): 1,
#              ('1982', 'Gastón'): 1,
#              ('pudiendo', 'administrar'): 1,
#              ('758', ','): 1,
#              ('Musa', '17'): 1,
#              ('Viascan', 'Castillo'): 1,
#              ('Héctor', 'GIOIA'): 2,
#              ('Tacuari', '119'): 3,
#              (';', 'Santa'): 1,
#              ('27682', '/'): 1,
#              ('Glorietas', ','): 1,
#              ('en', 'Ombú'): 1,
#              (',', 'cia'): 1,
#              ('mecánicas', '.'): 1,
#              ('adquiridos', 'por'): 3,
#              ('y', 'técnica'): 1,
#              ('realizadas', 'sin'): 1,
#              ('°', '20014'): 2,
#              ('234', ','): 7,
#              ('fiducia', 'transfiera'): 1,
#              ('Torres', ','): 12,
#              ('mexicano', ','): 8,
#              ('Laura', 'Piculin'): 2,
#              ('Cerioli', 'argentino'): 1,
#              ('531', ','): 19,
#              ('630', 'del'): 1,
#              ('técnicos', 'electrónicos'): 1,
#              ('662', 'de'): 1,
#              ('99', 'desde'): 2,
#              (')', 'don'): 1,
#              ('embarcaciones', 'para'): 1,
#              (')', 'ARQUITECTUM'): 1,
#              (')', 'MANAL'): 1,
#              ('dispuestas', 'a'): 8,
#              (',', 'fonobar'): 1,
#              (')', 'Integrantes'): 1,
#              ('privados', 'con'): 5,
#              ('corresponder', '.'): 3,
#              ('Mora', '420'): 2,
#              ('Unidos', '428'): 1,
#              ('FONTANA', 'y'): 1,
#              ('De', 'Sousa'): 2,
#              ('pios', 'o'): 2,
#              ('6075', 'S'): 1,
#              (';', 'ADMINISTRACIÓN'): 1,
#              ('Rodríguez', '1352'): 2,
#              ('Patos', '2584'): 1,
#              ('en', 'oftalmología'): 1,
#              ('con', 'Calanit'): 1,
#              ('Pasaje', 'Dr'): 1,
#              ('NAUTICA', 'S'): 3,
#              ('740', '–'): 1,
#              ('y', 'Domicilio'): 43,
#              ('..', 'Socios'): 1,
#              (',', 'gráfico'): 14,
#              ('seguro', 'de'): 8,
#              ('°', '2903'): 1,
#              ('IVANISSEVICH', ','): 20,
#              ('Bracalenti', ','): 1,
#              ('Jaime', 'Sartori'): 1,
#              ('La', 'Quebrada'): 2,
#              ('diseño', 'industrial'): 2,
#              ('su', 'actuación'): 4,
#              ('productos', 'agrícola'): 8,
#              ('Ravignani', '2330'): 3,
#              ('España', 'PAB'): 1,
#              ('CUIT', '27054971325'): 1,
#              (',', 'marcos'): 1,
#              ('Roberto', 'GONZÁLEZ'): 3,
#              ('”', '4'): 3,
#              ('Nº', '853'): 2,
#              ('53149', '/'): 1,
#              ('Nº', '596'): 7,
#              ('GARCIA', 'COSTERO'): 1,
#              ('Nº', '1351'): 3,
#              ('BELLINI', 'PARRA'): 1,
#              ('Temperley', ','): 12,
#              ('servicio', 'al'): 3,
#              ('NEGRO', 'S'): 1,
#              ('copiado', ','): 1,
#              ('°', '22653'): 1,
#              ('Rivadavia', '5444'): 2,
#              ('509', ';'): 1,
#              (',', 'fraccionar'): 9,
#              ('Autorizada', 'antes'): 1,
#              ('Ariel', 'Claudio'): 2,
#              ('RADI', 'MAS'): 1,
#              ('.', '061'): 12,
#              ('procesos', 'tanto'): 1,
#              ('personas', 'debidamente'): 2,
#              ('intervenga', ','): 5,
#              ('125', ','): 7,
#              ('50198', '/'): 1,
#              ('Diana', 'Margarita'): 2,
#              ('y', 'representantes'): 7,
#              ('precedentemente', 'será'): 1,
#              ('Au', 'torizado'): 1,
#              ('subpartes', ','): 1,
#              ('GERARDO', 'LOPEZ'): 17,
#              ('°', '37881'): 1,
#              ('oficinas', 'en'): 3,
#              ('Soledad', 'Nuñez'): 1,
#              ('sede', 'se'): 1,
#              ('1663', ','): 2,
#              ('acordándoles', 'la'): 1,
#              ('GUTIERRREZ', '.'): 2,
#              ('ARGENTA', 'CLEAN'): 1,
#              ('matrículas', 'respectivas'): 1,
#              ('Decreto', 'Reglamentario'): 2,
#              ('894', '.'): 3,
#              ('maquinaria', 'textil'): 4,
#              ('productos', 'médicos'): 10,
#              ('Joseph', 'TRIPIER'): 2,
#              ('15531', '/'): 1,
#              ('Alejandro', 'SCAPPINI'): 1,
#              ('59711', '/'): 1,
#              ('Alejandro', 'Mahmud'): 1,
#              ('2653', '/'): 1,
#              ('Alejandro', 'CZARNY'): 1,
#              ('grasos', 'de'): 1,
#              ('damas', ','): 2,
#              ('ganadería', 'mediante'): 1,
#              ('asistencia', 'al'): 2,
#              ('demás', 'medios'): 2,
#              ('Mora', 'Tali'): 1,
#              ('105498', 'según'): 1,
#              ('habilitante', '.'): 209,
#              ('privada', 'mediante'): 6,
#              ('128', 'Tigre'): 1,
#              ('género', 'o'): 2,
#              ('mismo', 'a'): 2,
#              ('817', '.'): 5,
#              ('en', 'citada'): 1,
#              ('Selene', 'RESTAGNO'): 2,
#              ('553', 'Jorge'): 5,
#              ('muelles', '.'): 1,
#              ('°', '46002'): 1,
#              ('la', 'ciduad'): 2,
#              ('mixtos', 'o'): 5,
#              ('seres', 'humanos'): 1,
#              ('terceros', 'alternativas'): 2,
#              ('58051', '/'): 1,
#              ('14618087', '-'): 1,
#              ('°:', '563'): 1,
#              ('completas', 'en'): 1,
#              ('18404306', '-'): 2,
#              ('1', '),'): 3,
#              (')', 'Paroissien'): 1,
#              ('Y', 'TRES'): 1,
#              ('Registro', '1967'): 1,
#              ('del', 'trabajo'): 6,
#              ('Guitelman', 'y'): 1,
#              ('1711', ','): 2,
#              (',', 'serigrafía'): 2,
#              ('y', 'corta'): 2,
#              ('en', 'Extranjero'): 1,
#              ('4365', 'C'): 1,
#              ('“', 'ENER'): 1,
#              ('Corrientes', '3339'): 2,
#              (',', 'Comercio'): 2,
#              ('soltera', 'DNI'): 1,
#              ('préstamos', ','): 39,
#              ('CARYAN', 'S'): 1,
#              ('MINNETTI', '.-'): 1,
#              ('Panella', ','): 1,
#              ('fabricación', 'nacional'): 1,
#              ('BUTMAN', ','): 1,
#              ('PUSTILNIK', ','): 2,
#              ('-', '12927501'): 1,
#              ('realizacion', 'de'): 3,
#              ('Gabriela', 'Mistral'): 3,
#              ('en', 'Huergo'): 1,
#              ('o', 'permisos'): 3,
#              ('estructuras', 'exhibidoras'): 1,
#              ('Incas', '3423'): 1,
#              ('.', '211'): 9,
#              ('17347258', ','): 1,
#              ('docencia', 'e'): 4,
#              ('Alfredo', 'Soares'): 2,
#              ('Silvia', 'Inés'): 2,
#              ('Lisandro', 'Frene'): 1,
#              (',', 'específicamente'): 1,
#              ('uso', 'personal'): 1,
#              ('pertinentes', 'como'): 1,
#              ('Las', 'Corzuelas'): 1,
#              ('4', 'piso'): 6,
#              ('Cadiz', 'Circle'): 1,
#              ('480', ','): 9,
#              ('debidamente', 'habilitadas'): 2,
#              ('NORAMBUENA', 'RODRIGUEZ'): 1,
#              ('TORU', 'SA'): 1,
#              ('Ferroviaria', ','): 2,
#              ('o', 'beneficiarios'): 3,
#              ('’', 'Ciudad'): 1,
#              ('Laura', 'Pellini'): 1,
#              ('comidas', 'rapidas'): 1,
#              (':', 'Roque'): 4,
#              ('Cervera', ','): 1,
#              ('ingresos', 'de'): 1,
#              ('4570', ','): 2,
#              ('venderlas', ','): 1,
#              ('24205971', '-'): 1,
#              ('respectivos', 'contratos'): 3,
#              (':-', '1'): 1,
#              ('Adrián', 'ORIANI'): 2,
#              ('fideicomisos', 'traslativos'): 2,
#              ('Bonino', 'registro'): 2,
#              ('29100', '/'): 1,
#              (',', 'Blanco'): 6,
#              ('quinto', 'piso'): 5,
#              ('y', 'clínica'): 1,
#              ('comercial', 'o'): 12,
#              ('Martinez', 'Vallano'): 1,
#              ('Martin', 'Guerrico'): 2,
#              ('indeterminado', 'para'): 1,
#              ('DTO', '.'): 1,
#              ('Eliana', 'Castignano'): 1,
#              ('Nº', '229'): 1,
#              ('realizar', 'asesoramiento'): 5,
#              ('421', '.'): 6,
#              ('-', '86'): 1,
#              ('volúmenes', 'referidos'): 1,
#              ('Emilio', 'CORREA'): 1,
#              ('medios', 'disponibles'): 1,
#              ('la', 'intersección'): 2,
#              ('visible', 'o'): 4,
#              ('-', '10126823'): 1,
#              (':', 'Carmen'): 8,
#              ('Capítulo', 'III'): 4,
#              ('o', 'externos'): 1,
#              ('Fabiana', 'Emilia'): 4,
#              ('083', 'y'): 2,
#              ('“', 'CRED'): 1,
#              ('DIAGONAL', 'CAPITAL'): 2,
#              ('”,', 'Rincón'): 1,
#              ('productos', 'informáticos'): 3,
#              ('Denomina', 'MAPAMAS'): 1,
#              ('Gustavo', 'Mario'): 2,
#              ('95', ','): 25,
#              ('°:', '34'): 1,
#              ('1150', 'Piso'): 1,
#              ('1627', 'CABA'): 2,
#              ('libro', '61'): 5,
#              ('GFR', 'S'): 1,
#              ('hasta', 'las'): 13,
#              ('extranjera', 'inscripta'): 2,
#              ('Nº', '1656'): 1,
#              ('FORT', '-'): 1,
#              ('DNI', '27592589'): 1,
#              ('Folio', '200'): 1,
#              ('Country', 'El'): 3,
#              ('Ninfa', 'LLANOS'): 1,
#              ('gaseosas', ','): 3,
#              ('nº105', ','): 1,
#              (',', 'cédulas'): 11,
#              ('nacio', '11'): 1,
#              ('en', '200000'): 1,
#              ('a', 'sus'): 20,
#              ('Seguros', ','): 1,
#              (')', 'Colombres'): 1,
#              ('Araoz', '297'): 1,
#              ('Callao', '157'): 1,
#              ('su', 'número'): 1,
#              ('cargo', 'de'): 148,
#              ('28224', '/'): 1,
#              ('Repossi', ','): 1,
#              ('petroquímicos', 'en'): 1,
#              ('administraciones', 'consignaciones'): 1,
#              ('456', 'piso'): 2,
#              ('SPG', 'EDIFICA'): 3,
#              ('Matías', 'Jorge'): 2,
#              ('1', 'CABA'): 55,
#              ('o', 'sublicenciar'): 1,
#              ('alcóholicas', 'o'): 1,
#              ('Daitch', ','): 2,
#              (',', 'mandato'): 44,
#              ('.-', 'Todos'): 8,
#              ('.', '364'): 11,
#              ('Sanguinetti', 'en'): 1,
#              ('de', 'brindar'): 1,
#              ('en', 'construcciones'): 1,
#              ('de', 'Elvira'): 1,
#              ('le', 'tiene'): 1,
#              ('MUSTAFA', ','): 1,
#              ('Renzulli', '.'): 1,
#              ('forma', 'exclusiva'): 4,
#              (',', 'desguace'): 1,
#              ('otras', 'las'): 1,
#              ('mandataria', '.'): 1,
#              ('DNI', '93355207'): 1,
#              ('Iraola', 'II'): 2,
#              ('Octavio', 'Augusto'): 1,
#              ('carpintería', 'de'): 2,
#              ('TI', '54402'): 1,
#              ('Moreno', '575'): 1,
#              ('Javier', 'FERNANDEZ'): 2,
#              (':', 'duración'): 1,
#              ('TRES', '.'): 1,
#              ('federalvalores', '@'): 1,
#              ('normas', 'reglamentarias'): 13,
#              ('reglamentarias', 'a'): 1,
#              ('Orlando', 'VERA'): 1,
#              ('634', 'y'): 1,
#              ('definición', 'que'): 1,
#              ('engrase', 'y'): 3,
#              ('de', 'permisos'): 4,
#              ('en', 'realidad'): 1,
#              ('Río', 'Negro'): 10,
#              ('de', 'Oliveira'): 3,
#              ('sistema', 'a'): 1,
#              ('Mabel', 'Molina'): 1,
#              ('mismos', '.-'): 3,
#              ('tierras', 'en'): 2,
#              (',', 'sudafricana'): 1,
#              (':', 'Peinado'): 1,
#              ('-', '52751673'): 1,
#              ('18837526', '-'): 1,
#              ('Avenida', 'Diaz'): 2,
#              ('“', 'SOCIEDAD'): 1,
#              (',', 'Obarrio'): 1,
#              ('mercancías', ','): 5,
#              ('publicas', 'o'): 17,
#              ('PRESIDENTE', 'a'): 2,
#              ('SLONIMSKY', ','): 4,
#              ('-', '14769523'): 1,
#              ('respetando', 'las'): 1,
#              ('mariano', 'javier'): 1,
#              (',', 'celebración'): 2,
#              ('.', 'AS'): 3,
#              ('KACHANI', ','): 1,
#              ('tocador', 'y'): 2,
#              ('LEANDRO', 'N'): 3,
#              ('eléctricas', 'a'): 1,
#              ('8ºpiso', ','): 1,
#              ('Mirta', 'Graciela'): 1,
#              ('real', 'Américo'): 1,
#              ('11453', '.'): 2,
#              ('Servicio', 'técnico'): 3,
#              ('creara', '.'): 1,
#              ('Natalia', 'Soledad'): 4,
#              ('-,', 'de'): 1,
#              (',', 'simples'): 1,
#              ('Alejandro', 'Roberto'): 4,
#              ('habilitando', 'toda'): 1,
#              ('constituyeron', 'TUTTOCASA'): 1,
#              ('fonoaudióloga', ','): 1,
#              ('04616117', '-'): 1,
#              (',', 'incluso'): 178,
#              ('21', 'C'): 2,
#              ('DNI', '32478516'): 1,
#              ('y', 'conocimientos'): 4,
#              ('citotoxicidad', ','): 2,
#              (':', 'Lidia'): 8,
#              ('sitios', 'o'): 1,
#              ('día', 'para'): 1,
#              ('en', '10'): 8,
#              ('e', 'Iván'): 2,
#              ('financiación', ';'): 1,
#              ('DNI', '24587143'): 1,
#              ('Nº', '1879'): 11,
#              ('Corrientos', '456'): 1,
#              ('Alejandra', 'Korchmar'): 2,
#              (',', 'termooceánica'): 4,
#              ('actividad', 'así'): 6,
#              ('de', 'comerciales'): 3,
#              ('o', 'extranjeras'): 78,
#              ('servicios', 'referidos'): 4,
#              ('57', '”'): 1,
#              ('SILVA', 'RODRIGUES'): 2,
#              ('Ceferino', 'Ramirez'): 1,
#              (',', 'textil'): 6,
#              ('en', 'Cucha'): 1,
#              ('y', 'vinculadas'): 3,
#              ('domicilio', 'Honorio'): 3,
#              ('Compañía', 'Gerenciadora'): 1,
#              ('12902373', '-'): 1,
#              ('385', '.'): 5,
#              ('Hoz', 'de'): 1,
#              ('DE', 'GAS'): 1,
#              ('Lopez', '.'): 3,
#              ('-', '40809067'): 1,
#              ('MARIN', 'CAMPOSANO'): 2,
#              ('ley', ','): 14,
#              ('gestión', 'integrada'): 1,
#              ('132', 'del'): 2,
#              ('2016', 'Esc'): 12,
#              ('presidente', 'Ricardo'): 2,
#              ('1574', ','): 10,
#              ('Guillermo', 'Domingo'): 2,
#              ('Martín', 'Diego'): 2,
#              ('Lavalle', '715'): 4,
#              ('Nº', '1404'): 2,
#              ('.-', 'Importación'): 5,
#              (',', 'DNI40543882'): 1,
#              ('de', 'municipales'): 1,
#              ('29986646', '-'): 1,
#              ('mismos', 'contratos'): 1,
#              ('Niña', '315'): 2,
#              ('°:', '485'): 1,
#              ('y', 'Ermidio'): 1,
#              ('escritura', '53'): 1,
#              ('Ortega', 'y'): 12,
#              (':', 'proporcionar'): 1,
#              ('o', 'sus'): 25,
#              ('Nº', '776'): 9,
#              ('automóviles', ';'): 1,
#              ('árboles', 'y'): 1,
#              ('lo', 'requieran'): 382,
#              ('3717', 'C'): 25,
#              (',', 'vinilo'): 1,
#              ('°', '20534'): 1,
#              ('08', ','): 2,
#              ('60572891', '-'): 2,
#              ('Representación', 'Legal'): 176,
#              ('carnicerías', ','): 1,
#              ('25791019', 'Empresaria'): 1,
#              ('EJERICIO', ':'): 1,
#              ('años', 'empresaria'): 1,
#              ('12', '/'): 1552,
#              ('CARCACHA', '.'): 1,
#              ('DI', 'GUGLIELMO'): 2,
#              ('edición', 'de'): 9,
#              ('EXPORTADORA', 'SAN'): 2,
#              ('del', 'Oeste'): 1,
#              ('Supl', '.'): 1,
#              ('Harrison', 'constituyendo'): 1,
#              ('3130', '.'): 1,
#              ('Crovetto', ','): 1,
#              ('Fedrico', 'Daniel'): 1,
#              ('relacionado', 'de'): 2,
#              ('Sandra', 'Natacha'): 9,
#              ('o', 'importados'): 6,
#              ('Nahir', 'Solís'): 2,
#              ('Alfredo', 'Marini'): 1,
#              ('prestamos', 'personales'): 4,
#              ('Cristina', 'POLANZAN'): 1,
#              (',', 'mercadearías'): 1,
#              ('directores', 'Costa'): 1,
#              ('con', 'Hernán'): 1,
#              ('Nº', '658'): 3,
#              ('internacional', ':'): 1,
#              ('Mayo', '.'): 4,
#              ('Fe', '2206'): 1,
#              ('contratos', 'y'): 109,
#              ('4847496', ','): 1,
#              ('1472', 'Parana'): 1,
#              ('Síndico', 'suplente'): 1,
#              ('DIRECTORES', 'TITULARES'): 9,
#              ('Miguel', 'García'): 1,
#              ('residuos', 'recolección'): 2,
#              ('2016', 'mediante'): 1,
#              ('del', 'petróleo'): 28,
#              ('CACACE', ','): 1,
#              (':', 'Maipu'): 5,
#              ('corporaciones', 'comerciales'): 1,
#              ('poseer', 'por'): 1,
#              ('Nº', '2129'): 3,
#              (')', 'adoptando'): 1,
#              ('46', '.-'): 1,
#              ('Encalada', '5451'): 3,
#              ('fotógrafo', ','): 1,
#              ('condones', ','): 1,
#              ('2701', 'C'): 1,
#              ('empresaria', ','): 216,
#              ('ingeniería', 'ambiental'): 1,
#              ('o', 'espacial'): 2,
#              ('Y', 'c'): 8,
#              ('1474', 'piso'): 1,
#              ('Derecho', 'Real'): 1,
#              ('mora', ','): 1,
#              ('795', 'Fernando'): 1,
#              ('Calvo', '854'): 1,
#              (';', 'corte'): 1,
#              ('AR', '&'): 2,
#              ('caución', '.'): 5,
#              ('.', '671'): 5,
#              (':', 'Aceptación'): 3,
#              ('Y', 'Fernández'): 1,
#              ('Edgar', 'Wiliam'): 2,
#              (',', 'Carlos'): 34,
#              ('49860', '/'): 1,
#              ('suministro', 'y'): 6,
#              ('liquidez', 'y'): 1,
#              ('Ninive', 'Mirel'): 2,
#              (':', 'Kun'): 1,
#              ('artefactos', 'sanitarios'): 3,
#              ('revistas', ','): 31,
#              ('modelos', 'operativos'): 1,
#              ('DEMASI', ','): 1,
#              ('20173393', '-'): 1,
#              ('Alicia', 'Telma'): 3,
#              ('19', 'Maria'): 3,
#              ('mantenimiento', ';'): 3,
#              ('embarcaciones', ','): 9,
#              ('),', 'telemercadeo'): 1,
#              ('-', '28324952'): 1,
#              ('hará', 'por'): 3,
#              ('Titular', 'del'): 21,
#              ('computaciones', ','): 1,
#              (',', 'actuación'): 1,
#              ('de', 'piezas'): 12,
#              ('.”,', 'CUIT'): 7,
#              ('anónimas', 'que'): 1,
#              ('sumar', 'valor'): 1,
#              ('nutrición', 'deportivos'): 2,
#              ('de', '17'): 1,
#              ('Sra', '.'): 3,
#              ('CASINOS', '-'): 1,
#              ('1069', 'Alejandro'): 1,
#              ('37417362', '-'): 1,
#              ('de', 'lunch'): 40,
#              ('SUSSIK', '.-'): 1,
#              ('Nº', '997'): 4,
#              ('°', '180732'): 1,
#              ('1468', 'de'): 1,
#              ('TELEVISION', ','): 1,
#              ('Monopoli', 'como'): 1,
#              ('%.-', 'Resto'): 1,
#              ('desarrollo', 'orientados'): 1,
#              ('°', '26077'): 1,
#              ('Moyano', 'y'): 2,
#              (':', 'Granaderos'): 1,
#              ('y', '123'): 2,
#              ('Villate', '3020'): 1,
#              ('KARPOWICZ', 'todos'): 1,
#              (',', 'competencias'): 2,
#              ('°', '30'): 13,
#              ('6385', ','): 1,
#              ('Claudia', 'Leticia'): 1,
#              ('estudios', 'contables'): 1,
#              ('Escribana', 'Renata'): 1,
#              ('PESOS', 'DOSCIENTOS'): 5,
#              ('Fabián', 'Marcelo'): 1,
#              ('privada', 'para'): 1,
#              ('564', 'Remedios'): 1,
#              ('El', 'Transporte'): 1,
#              ('TREVES', ','): 1,
#              ('especie', 'de'): 30,
#              ('interconectadas', ','): 1,
#              ('Suplente', 'todos'): 2,
#              ('14326891', '-'): 2,
#              ('jose', 'ignacio'): 1,
#              ('°', '2285'): 1,
#              ('commerce', '”.-'): 1,
#              (',', 'Ercilla'): 1,
#              ('1621', 'piso'): 2,
#              ('huellas', 'mineras'): 2,
#              ('269', 'Elizabeth'): 1,
#              ('Nº', '422'): 1,
#              ('conforme', 'la'): 14,
#              ('específica', 'de'): 1,
#              ('liquidas', 'y'): 1,
#              ('”', '–'): 3,
#              ('.', '808'): 11,
#              ('-', '10129500'): 1,
#              ('Ley', 'autorice'): 1,
#              ('o', 'disposición'): 3,
#              ('sistema', 'oral'): 1,
#              ('directos', 'e'): 5,
#              ('cumplimiento', 'ante'): 13,
#              ('exterior', 'directamente'): 1,
#              ('Financieras', 'no'): 1,
#              ('prefabricadas', '.'): 1,
#              ('°', '29014'): 1,
#              ('As', '..;'): 1,
#              ('contratados', 'a'): 4,
#              ('Monseñor', 'J'): 1,
#              ('descripta', 'en'): 6,
#              ('20005267', '-'): 1,
#              ('754', 'de'): 2,
#              ('-', '10728212'): 1,
#              ('3346', 'Piso'): 1,
#              ('Nº', '1267'): 1,
#              ('farmaceutico', ','): 1,
#              ('locataria', ';'): 2,
#              ('dice', '“'): 4,
#              ('trozado', ','): 4,
#              ('BUMAGA', 'S'): 2,
#              ('escisión', ','): 1,
#              ('Cleland', ','): 1,
#              ('ROTELA', 'de'): 1,
#              (')', 'Jonatan'): 4,
#              ('requiera', 'en'): 6,
#              ('23203245', ','): 1,
#              ('masas', 'secas'): 1,
#              (';', 'registrar'): 1,
#              ('Soares', 'Gache'): 2,
#              ('geológicas', 'y'): 1,
#              ('y', 'supermercados'): 2,
#              ('proveer', 'redes'): 1,
#              ('San', 'Vladimiro'): 1,
#              ('-', '29499592'): 1,
#              ('domicilio', 'constituido'): 20,
#              ('o', 'existiera'): 1,
#              ('escritura', '222'): 1,
#              ('088', ','): 3,
#              ('sin', 'alcohol'): 85,
#              ('Falcón', 'Nº'): 1,
#              (',', 'asesoramiento'): 118,
#              ('Berdichevsky', 'Director'): 29,
#              ('1298', 'Florencio'): 1,
#              ('hasta', 'el'): 5,
#              ('61', 'Pine'): 1,
#              ('Establecimientos', 'de'): 1,
#              ('la', 'hotelería'): 19,
#              ('BEHL', 'y'): 1,
#              ('Fernando', 'BELLAGAMBA'): 1,
#              ('Morano', 'autorizada'): 1,
#              ('INTERNATIONAL', 'SOCIEDAD'): 1,
#              ('/', '74'): 61,
#              ('“', '606'): 1,
#              ('/', '016'): 1,
#              ('requieran', 'una'): 1,
#              ('Bouchard', '1580'): 1,
#              ('domicilio', 'Zabala'): 1,
#              ('Vega', '5825'): 1,
#              ('DEL', '14'): 1,
#              ('propias', 'o'): 73,
#              ('16', 'debe'): 2,
#              ('32873', '/'): 1,
#              ('en', 'Matheu'): 1,
#              ('Resolución', '7'): 3,
#              ('47330', '/'): 1,
#              ('Libro', '60'): 5,
#              ('Representación', '.'): 2,
#              ('González', 'ambos'): 1,
#              ('para', 'efectuarlos'): 1,
#              ('HERNAN', 'HIRSCH'): 1,
#              ('servicio', 'y'): 14,
#              ('1848', 'de'): 1,
#              ('con', 'Jessica'): 1,
#              ('Energético', 'Mayorista'): 1,
#              ('-', '26286322'): 1,
#              ('contratos', 'telefónicos'): 1,
#              (',', 'transferencia'): 8,
#              ('análisis', 'físico'): 1,
#              (',', 'registrándose'): 1,
#              ('-', '92875743'): 1,
#              ('como', 'impuestos'): 1,
#              (',', 'giros'): 14,
#              ('40640658', 'nacida'): 1,
#              ('siete', 'directores'): 1,
#              ('viajes', '.'): 2,
#              ('contrataciones', 'de'): 2,
#              (',', 'software'): 42,
#              ('sus', 'posibilidades'): 7,
#              ('derechos', 'litigiosos'): 1,
#              ('está', 'a'): 23,
#              ('208', ','): 8,
#              ('o', 'permuta'): 32,
#              ('La', 'Montura'): 2,
#              (':', 'SERGIO'): 1,
#              ('cierre', 'de'): 30,
#              ('.', '885'): 9,
#              ('GAILAN', 'S'): 2,
#              ('LALANDA', 'S'): 1,
#              ('virtual', 'especialmente'): 1,
#              ('Romina', 'Carla'): 1,
#              ('explotación', 'en'): 23,
#              ('Mariana', 'DEL'): 2,
#              ('los', 'funcionarios'): 1,
#              ('cuatriciclos', ','): 2,
#              ('España', ';'): 2,
#              ('1970', 'domiciliado'): 1,
#              ('MANTENIMIENTO', 'y'): 1,
#              ('GUARINI', ','): 1,
#              ('con', 'vinculación'): 4,
#              ('procedimientos', 'con'): 1,
#              ('y', 'aprovisionamiento'): 1,
#              ('Elena', 'Grin'): 1,
#              ('3475', 'C'): 2,
#              ('°', '56798'): 1,
#              ('Isabel', 'Carranza'): 1,
#              ('2138', ','): 3,
#              ('innominados', '-'): 1,
#              (',', 'órdenes'): 4,
#              ('7137', ','): 1,
#              (')', 'JOJMA'): 1,
#              ('Besada', ','): 2,
#              ('NAUTICA', 'SA'): 1,
#              ('realizar', '“'): 1,
#              ('Agencia', 'de'): 6,
#              ('Live', 'Nation'): 2,
#              ('lleva', 'el'): 1,
#              ...})

# %% [markdown]
# El código sirve para n-gramas en general.
#
# Tareas pendientes:
# - Agregar marcadores de principio y final de oración
# - Contar n-gramas y (n-1)-gramas al mismo tiempo.

# %% [markdown]
# # Generando Lenguaje Natural
#
# El siguiente modelo de bigramas se aprende a partir de dos oraciones:
# - "el gato come pescado"
# - "la gata come salmón"

# %%
probs = {
    '<s>': {'el': 0.5, 'la': 0.5},
    # '<s>': {'el': 0.6, 'la': 0.2, 'los': 0.1, 'las': 0.1},
    'el': {'gato': 1.0},
    'gato': {'come': 1.0},
    'come': {'pescado': 0.5, 'salmón': 0.5},
    'pescado': {'.': 1.0},
    '.': {'</s>': 1.0},
    'la': {'gata': 1.0},
    'gata': {'come': 1.0},
    'salmón': {'.': 1.0},
}

list(probs['<s>'].items())  # convertir un diccionario a lista de pares
# Out:
# [('la', 0.5), ('el', 0.5)]

# %% [markdown]
# Cada entrada del diccionario contiene una distribución discreta finita para la palabra siguiente dada la palabra anterior. Samplear de una distribución discreta finita es tan fácil como samplear un número al azar entre 0 y 1 y ver en qué región cae (ver [Wikipedia](https://en.wikipedia.org/wiki/Pseudo-random_number_sampling#Finite_discrete_distributions)).
#
# Empezamos sampleando la primer palabra:

# %%
from random import random

def sample(problist):
    r = random()  # entre 0 y 1
    i = 0
    word, prob = problist[0]
    acum = prob
    while r > acum:
        i += 1
        word, prob = problist[i]
        acum += prob
    
    return word

sample(list(probs['<s>'].items()))
# Out:
# 'la'

# %% [markdown]
# Podemos ver que el resultado del sampleo se corresponde con las probabilidades:

# %%
results = [sample(list(probs['<s>'].items())) for i in range(1000)]

from collections import Counter
print(Counter(results))
# Out:
# Counter({'el': 505, 'la': 495})

# %% [markdown]
# **Observaciones:**
# - Si se ordena la lista de probabilidades de mayor a menor, el sampling es más rápido.
# - El sampling también se puede hacer usando [random.choices](https://docs.python.org/3/library/random.html#random.choices) de python
# ó [random.choice](https://stackoverflow.com/questions/11373192/generating-discrete-random-variables-with-specified-weights-using-scipy-or-numpy) de numpy.
#
# Ahora veamos cómo samplear una oración completa:

# %%
word = '<s>'
while word != '</s>':
    problist = list(probs[word].items())
    word = sample(problist)
    print(word)
# Out:
# la
# gata
# come
# pescado
# .
# </s>

# %% [markdown]
# Acá se ve que se pueden generar oraciones nuevas (no vistas en tiempo de entrenamiento).
#
# Tareas pendientes:
# - adaptar el código a n-gramas en general: usar tuplas como claves en probs!
# - precalcular las listas ordenadas de mayor a menor (ver sorted_prob en los tests)
